# %% [markdown]
# <a href="https://colab.research.google.com/github/A1ienSword/Pattern-recognition-labs/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_8_%D0%9A%D0%BE%D1%81%D1%82%D0%B8%D1%86%D1%8B%D0%BD_%D0%92%D0%92_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python-headless tqdm
# Out:
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python-headless) (2.0.2)

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
from multiprocessing import Pool, cpu_count
from functools import partial
from pathlib import Path

# %%
def crop_to_content(img):
    """Обрезает пустые поля вокруг символа (по белому фону)."""
    # Если изображение цветное, переводим в градации серого
    if len(img.shape) == 3:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    else:
        gray = img
    # Бинаризация: всё светлее 250 становится белым (255), остальное — чёрным (0)
    _, thresh = cv2.threshold(gray, 250, 255, cv2.THRESH_BINARY)
    # Находим координаты всех НЕбелых пикселей (255 - thresh инвертирует изображение)
    coords = cv2.findNonZero(255 - thresh)
    if coords is None:
        # Если не найдено ни одного непустого пикселя — возвращаем исходное изображение
        return img
    # Получаем прямоугольник, минимально охватывающий все найденные пиксели
    x, y, w, h = cv2.boundingRect(coords)
    if w == 0 or h == 0:
        # Если обрезка дала нулевой размер — возвращаем исходное изображение
        return img
    # Вырезаем найденный прямоугольник из исходного изображения
    cropped = img[y:y+h, x:x+w]
    return cropped

def resize_and_pad(img, size):
    """Масштабирует изображение с сохранением пропорций и центрирует на квадратном холсте."""
    h, w = img.shape[:2]
    if h == 0 or w == 0:
        # Если изображение пустое — возвращаем белое изображение нужного размера
        if len(img.shape) == 2:
            return np.full((size, size), 255, dtype=np.uint8)
        else:
            return np.full((size, size, 3), 255, dtype=np.uint8)
    # Вычисляем масштаб так, чтобы большая сторона стала равна size
    scale = size / max(h, w)
    if scale <= 0:
        # Защита от деления на ноль или отрицательного масштаба
        scale = 1.0
    new_w, new_h = int(w * scale), int(h * scale)
    if new_w == 0 or new_h == 0:
        # Если после масштабирования размер стал нулевым — возвращаем белое изображение
        if len(img.shape) == 2:
            return np.full((size, size), 255, dtype=np.uint8)
        else:
            return np.full((size, size, 3), 255, dtype=np.uint8)
    # Масштабируем изображение
    img_resized = cv2.resize(img, (new_w, new_h), interpolation=cv2.INTER_NEAREST)
    # Вычисляем отступы для центрирования изображения на квадратном фоне
    pad_top = (size - new_h) // 2
    pad_bottom = size - new_h - pad_top
    pad_left = (size - new_w) // 2
    pad_right = size - new_w - pad_left
    # Цвет фона — белый (255)
    if len(img.shape) == 2:
        color = [255]
    else:
        color = [255, 255, 255]
    # Добавляем отступы (паддинг) вокруг изображения
    img_padded = cv2.copyMakeBorder(
        img_resized, pad_top, pad_bottom, pad_left, pad_right,
        cv2.BORDER_CONSTANT, value=color
    )
    return img_padded

def to_binary(img):
    """
    Преобразует изображение к чёрно-белому (только #FFFFFF и #000000),
    учитывая возможный цветной фон и цвет символа.
    """

    # Конвертируем в grayscale, если изображение цветное
    if len(img.shape) == 3:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    else:
        gray = img.copy()

    # Оцениваем цвет фона: среднее значение в 4-х углах (по 10x10 пикселей)
    h, w = gray.shape
    corner_size = 10
    corners = [
        gray[0:corner_size, 0:corner_size],
        gray[0:corner_size, w-corner_size:w],
        gray[h-corner_size:h, 0:corner_size],
        gray[h-corner_size:h, w-corner_size:w]
    ]
    bg_color = np.mean([np.mean(c) for c in corners])

    # Если фон тёмный (меньше 127), инвертируем изображение, чтобы фон стал светлым
    if bg_color < 127:
        gray = 255 - gray

    # Применяем адаптивный порог (лучше работает при неравномерном освещении)
    binary = cv2.adaptiveThreshold(
        gray,
        maxValue=255,
        adaptiveMethod=cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
        thresholdType=cv2.THRESH_BINARY,
        blockSize=15,
        C=10
    )

    # После adaptiveThreshold символы — белые, фон — чёрный, инвертируем чтобы символы были чёрными
    binary = 255 - binary

    # Проверяем, что фон действительно белый, а символы — чёрные
    corners_bin = [
        binary[0:corner_size, 0:corner_size],
        binary[0:corner_size, w-corner_size:w],
        binary[h-corner_size:h, 0:corner_size],
        binary[h-corner_size:h, w-corner_size:w]
    ]
    bg_color_bin = np.mean([np.mean(c) for c in corners_bin])
    if bg_color_bin < 127:
        # Если фон всё ещё тёмный — инвертируем ещё раз
        binary = 255 - binary

    return binary

# %%
def process_image(args):
    # Распаковка аргументов: путь к исходному изображению, путь для сохранения, размер
    src_path, dst_path, size = args
    try:
        # Читаем изображение в цвете
        img = cv2.imread(str(src_path), cv2.IMREAD_COLOR)
        if img is None:
            print(f"Invalid image: {src_path}")
            return
        # Обрезаем пустые поля
        img = crop_to_content(img)
        # Масштабируем и центрируем на квадратном фоне
        img = resize_and_pad(img, size)
        # Переводим в чёрно-белое
        img = to_binary(img)
        # Сохраняем результат
        cv2.imwrite(str(dst_path), img)
    except Exception as e:
        print(f"Error processing {src_path}: {e}")

# %%
def prepare_filelist(input_dir, output_dir, size):
    tasks = []
    counters = {}  # Счётчик для каждой буквы

    # Рекурсивно обходим все файлы в input_dir
    for root, _, files in os.walk(input_dir):
        for file in files:
            # Пропускаем не-изображения
            if not file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
                continue
            rel_path = os.path.relpath(root, input_dir)
            parts = Path(rel_path).parts
            # Структура: train/GUID/LETTER
            if len(parts) < 2:
                continue
            label = parts[-1]  # Название буквы (метка)
            dst_folder = os.path.join(output_dir, label)
            os.makedirs(dst_folder, exist_ok=True)
            # Счётчик для уникальных имён файлов
            if label not in counters:
                counters[label] = 0
            dst_name = f"{counters[label]:04d}.png"
            counters[label] += 1

            src_path = os.path.join(root, file)
            dst_path = os.path.join(dst_folder, dst_name)
            tasks.append((src_path, dst_path, size))
    return tasks

# %%
def main(input_dir, output_dir, size):
    tasks = prepare_filelist(input_dir, output_dir, size)
    print(f"Всего изображений для обработки: {len(tasks)}")
    with Pool(processes=cpu_count()) as pool:
        list(tqdm(pool.imap_unordered(process_image, tasks), total=len(tasks)))
    print("Обработка завершена.")

# %%
# !apt-get install p7zip-full
# !p7zip -d dataset_2025.7z
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-8).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 8622323 bytes (8421 KiB)
#
# Extracting archive: dataset_2025.7z
# --
# Path = dataset_2025.7z
# Type = 7z
# Physical Size = 8622323
# Headers Size = 60271
# Method = LZMA:23
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 2515
# Files: 3754
# Size:       20601804
# Compressed: 8622323

# %%
# Параметры
INPUT_DIR = 'dataset_2025/test'
OUTPUT_DIR = 'processed_dataset/test'
SIZE = 64  # Задайте нужный размер NxN

main(INPUT_DIR, OUTPUT_DIR, SIZE)

# Параметры
INPUT_DIR = 'dataset_2025/train'
OUTPUT_DIR = 'processed_dataset/train'

main(INPUT_DIR, OUTPUT_DIR, SIZE)
# Out:
# Всего изображений для обработки: 1137
# 100%|██████████| 1137/1137 [00:01<00:00, 603.45it/s]
# Обработка завершена.
# Всего изображений для обработки: 2360
# 100%|██████████| 2360/2360 [00:02<00:00, 1037.95it/s]
# Обработка завершена.

# %%
# !zip -r processed_dataset.zip processed_dataset/
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   adding: processed_dataset/train/X/0017.png (deflated 4%)
#   adding: processed_dataset/train/X/0057.png (deflated 3%)
#   adding: processed_dataset/train/X/0001.png (deflated 1%)
#   adding: processed_dataset/train/X/0051.png (deflated 2%)
#   adding: processed_dataset/train/X/0003.png (stored 0%)
#   adding: processed_dataset/train/X/0004.png (deflated 0%)
#   adding: processed_dataset/train/X/0049.png (deflated 23%)
#   adding: processed_dataset/train/X/0010.png (deflated 3%)
#   adding: processed_dataset/train/X/0007.png (deflated 4%)
#   adding: processed_dataset/train/X/0023.png (deflated 2%)
#   adding: processed_dataset/train/X/0018.png (deflated 3%)
#   adding: processed_dataset/train/X/0009.png (stored 0%)
#   adding: processed_dataset/train/X/0013.png (deflated 3%)
#   adding: processed_dataset/train/X/0058.png (deflated 2%)
#   adding: processed_dataset/train/X/0016.png (deflated 7%)
#   adding: processed_dataset/train/X/0047.png (deflated 2%)
#   adding: processed_dataset/train/X/0045.png (deflated 12%)
#   adding: processed_dataset/train/X/0054.png (deflated 21%)
#   adding: processed_dataset/train/X/0032.png (deflated 5%)
#   adding: processed_dataset/train/X/0027.png (stored 0%)
#   adding: processed_dataset/train/X/0052.png (deflated 1%)
#   adding: processed_dataset/train/X/0043.png (deflated 8%)
#   adding: processed_dataset/train/X/0040.png (deflated 18%)
#   adding: processed_dataset/train/X/0050.png (deflated 52%)
#   adding: processed_dataset/train/X/0046.png (deflated 0%)
#   adding: processed_dataset/train/X/0048.png (deflated 8%)
#   adding: processed_dataset/train/X/0044.png (deflated 16%)
#   adding: processed_dataset/train/X/0041.png (deflated 20%)
#   adding: processed_dataset/train/X/0005.png (deflated 2%)
#   adding: processed_dataset/train/X/0053.png (deflated 18%)
#   adding: processed_dataset/train/X/0011.png (deflated 13%)
#   adding: processed_dataset/train/X/0033.png (deflated 2%)
#   adding: processed_dataset/train/X/0038.png (deflated 0%)
#   adding: processed_dataset/train/X/0034.png (deflated 0%)
#   adding: processed_dataset/train/X/0006.png (deflated 3%)
#   adding: processed_dataset/train/X/0029.png (deflated 5%)
#   adding: processed_dataset/train/X/0037.png (deflated 4%)
#   adding: processed_dataset/train/X/0021.png (deflated 1%)
#   adding: processed_dataset/train/X/0022.png (deflated 1%)
#   adding: processed_dataset/train/X/0028.png (deflated 3%)
#   adding: processed_dataset/train/X/0060.png (deflated 0%)
#   adding: processed_dataset/train/X/0031.png (deflated 2%)
#   adding: processed_dataset/train/X/0056.png (deflated 5%)
#   adding: processed_dataset/train/X/0030.png (deflated 3%)
#   adding: processed_dataset/train/X/0042.png (deflated 5%)
#   adding: processed_dataset/train/X/0019.png (deflated 5%)
#   adding: processed_dataset/train/X/0000.png (deflated 0%)
#   adding: processed_dataset/train/X/0020.png (deflated 2%)
#   adding: processed_dataset/train/X/0035.png (stored 0%)
#   adding: processed_dataset/train/4/ (stored 0%)
#   adding: processed_dataset/train/4/0024.png (deflated 27%)
#   adding: processed_dataset/train/4/0036.png (deflated 18%)
#   adding: processed_dataset/train/4/0012.png (deflated 12%)
#   adding: processed_dataset/train/4/0059.png (deflated 28%)
#   adding: processed_dataset/train/4/0065.png (deflated 18%)
#   adding: processed_dataset/train/4/0026.png (deflated 16%)
#   adding: processed_dataset/train/4/0014.png (deflated 10%)
#   adding: processed_dataset/train/4/0064.png (deflated 24%)
#   adding: processed_dataset/train/4/0063.png (deflated 28%)
#   adding: processed_dataset/train/4/0055.png (deflated 23%)
#   adding: processed_dataset/train/4/0008.png (deflated 8%)
#   adding: processed_dataset/train/4/0002.png (deflated 28%)
#   adding: processed_dataset/train/4/0025.png (deflated 30%)
#   adding: processed_dataset/train/4/0039.png (deflated 20%)
#   adding: processed_dataset/train/4/0015.png (deflated 29%)
#   adding: processed_dataset/train/4/0017.png (deflated 16%)
#   adding: processed_dataset/train/4/0057.png (deflated 15%)
#   adding: processed_dataset/train/4/0066.png (deflated 6%)
#   adding: processed_dataset/train/4/0001.png (deflated 11%)
#   adding: processed_dataset/train/4/0051.png (deflated 30%)
#   adding: processed_dataset/train/4/0003.png (deflated 15%)
#   adding: processed_dataset/train/4/0004.png (deflated 9%)
#   adding: processed_dataset/train/4/0049.png (deflated 9%)
#   adding: processed_dataset/train/4/0010.png (deflated 4%)
#   adding: processed_dataset/train/4/0007.png (deflated 36%)
#   adding: processed_dataset/train/4/0023.png (deflated 5%)
#   adding: processed_dataset/train/4/0018.png (deflated 23%)
#   adding: processed_dataset/train/4/0009.png (deflated 29%)
#   adding: processed_dataset/train/4/0013.png (deflated 11%)
#   adding: processed_dataset/train/4/0058.png (deflated 23%)
#   adding: processed_dataset/train/4/0016.png (deflated 17%)
#   adding: processed_dataset/train/4/0047.png (deflated 22%)
#   adding: processed_dataset/train/4/0045.png (deflated 6%)
#   adding: processed_dataset/train/4/0054.png (deflated 21%)
#   adding: processed_dataset/train/4/0032.png (deflated 13%)
#   adding: processed_dataset/train/4/0027.png (deflated 11%)
#   adding: processed_dataset/train/4/0052.png (deflated 18%)
#   adding: processed_dataset/train/4/0043.png (deflated 23%)
#   adding: processed_dataset/train/4/0040.png (deflated 19%)
#   adding: processed_dataset/train/4/0050.png (deflated 18%)
#   adding: processed_dataset/train/4/0046.png (deflated 23%)
#   adding: processed_dataset/train/4/0048.png (deflated 22%)
#   adding: processed_dataset/train/4/0044.png (deflated 14%)
#   adding: processed_dataset/train/4/0041.png (deflated 19%)
#   adding: processed_dataset/train/4/0005.png (deflated 10%)
#   adding: processed_dataset/train/4/0053.png (deflated 18%)
#   adding: processed_dataset/train/4/0011.png (deflated 2%)
#   adding: processed_dataset/train/4/0061.png (deflated 3%)
#   adding: processed_dataset/train/4/0033.png (deflated 3%)
#   adding: processed_dataset/train/4/0038.png (deflated 10%)
#   adding: processed_dataset/train/4/0034.png (deflated 2%)
#   adding: processed_dataset/train/4/0006.png (deflated 39%)
#   adding: processed_dataset/train/4/0029.png (deflated 5%)
#   adding: processed_dataset/train/4/0037.png (deflated 9%)
#   adding: processed_dataset/train/4/0021.png (deflated 38%)
#   adding: processed_dataset/train/4/0022.png (deflated 1%)
#   adding: processed_dataset/train/4/0028.png (deflated 5%)
#   adding: processed_dataset/train/4/0062.png (deflated 13%)
#   adding: processed_dataset/train/4/0060.png (deflated 23%)
#   adding: processed_dataset/train/4/0031.png (deflated 4%)
#   adding: processed_dataset/train/4/0056.png (deflated 17%)
#   adding: processed_dataset/train/4/0030.png (deflated 2%)
#   adding: processed_dataset/train/4/0042.png (deflated 27%)
#   adding: processed_dataset/train/4/0019.png (deflated 4%)
#   adding: processed_dataset/train/4/0000.png (deflated 11%)
#   adding: processed_dataset/train/4/0020.png (deflated 25%)
#   adding: processed_dataset/train/4/0035.png (deflated 0%)
#   adding: processed_dataset/train/7/ (stored 0%)
#   adding: processed_dataset/train/7/0024.png (deflated 4%)
#   adding: processed_dataset/train/7/0036.png (deflated 29%)
#   adding: processed_dataset/train/7/0012.png (stored 0%)
#   adding: processed_dataset/train/7/0059.png (deflated 26%)
#   adding: processed_dataset/train/7/0065.png (deflated 19%)
#   adding: processed_dataset/train/7/0026.png (stored 0%)
#   adding: processed_dataset/train/7/0014.png (deflated 21%)
#   adding: processed_dataset/train/7/0064.png (deflated 20%)
#   adding: processed_dataset/train/7/0063.png (stored 0%)
#   adding: processed_dataset/train/7/0055.png (deflated 52%)
#   adding: processed_dataset/train/7/0008.png (deflated 10%)
#   adding: processed_dataset/train/7/0002.png (stored 0%)
#   adding: processed_dataset/train/7/0025.png (deflated 4%)
#   adding: processed_dataset/train/7/0039.png (deflated 3%)
#   adding: processed_dataset/train/7/0015.png (deflated 26%)
#   adding: processed_dataset/train/7/0017.png (deflated 12%)
#   adding: processed_dataset/train/7/0057.png (deflated 9%)
#   adding: processed_dataset/train/7/0066.png (deflated 9%)
#   adding: processed_dataset/train/7/0001.png (deflated 5%)
#   adding: processed_dataset/train/7/0051.png (deflated 3%)
#   adding: processed_dataset/train/7/0003.png (deflated 5%)
#   adding: processed_dataset/train/7/0004.png (deflated 10%)
#   adding: processed_dataset/train/7/0049.png (deflated 1%)
#   adding: processed_dataset/train/7/0010.png (stored 0%)
#   adding: processed_dataset/train/7/0007.png (stored 0%)
#   adding: processed_dataset/train/7/0023.png (deflated 2%)
#   adding: processed_dataset/train/7/0018.png (deflated 3%)
#   adding: processed_dataset/train/7/0009.png (deflated 10%)
#   adding: processed_dataset/train/7/0013.png (stored 0%)
#   adding: processed_dataset/train/7/0058.png (deflated 9%)
#   adding: processed_dataset/train/7/0016.png (deflated 7%)
#   adding: processed_dataset/train/7/0047.png (deflated 5%)
#   adding: processed_dataset/train/7/0045.png (deflated 17%)
#   adding: processed_dataset/train/7/0054.png (deflated 52%)
#   adding: processed_dataset/train/7/0032.png (deflated 6%)
#   adding: processed_dataset/train/7/0027.png (stored 0%)
#   adding: processed_dataset/train/7/0052.png (deflated 18%)
#   adding: processed_dataset/train/7/0043.png (stored 0%)
#   adding: processed_dataset/train/7/0040.png (deflated 6%)
#   adding: processed_dataset/train/7/0050.png (deflated 9%)
#   adding: processed_dataset/train/7/0046.png (deflated 23%)
#   adding: processed_dataset/train/7/0048.png (deflated 2%)
#   adding: processed_dataset/train/7/0044.png (deflated 3%)
#   adding: processed_dataset/train/7/0041.png (deflated 18%)
#   adding: processed_dataset/train/7/0005.png (deflated 10%)
#   adding: processed_dataset/train/7/0053.png (deflated 29%)
#   adding: processed_dataset/train/7/0011.png (stored 0%)
#   adding: processed_dataset/train/7/0061.png (stored 0%)
#   adding: processed_dataset/train/7/0033.png (deflated 4%)
#   adding: processed_dataset/train/7/0038.png (deflated 28%)
#   adding: processed_dataset/train/7/0034.png (deflated 0%)
#   adding: processed_dataset/train/7/0006.png (deflated 15%)
#   adding: processed_dataset/train/7/0029.png (deflated 1%)
#   adding: processed_dataset/train/7/0037.png (deflated 10%)
#   adding: processed_dataset/train/7/0021.png (deflated 1%)
#   adding: processed_dataset/train/7/0022.png (deflated 2%)
#   adding: processed_dataset/train/7/0028.png (deflated 6%)
#   adding: processed_dataset/train/7/0062.png (deflated 6%)
#   adding: processed_dataset/train/7/0060.png (stored 0%)
#   adding: processed_dataset/train/7/0031.png (deflated 5%)
#   adding: processed_dataset/train/7/0056.png (deflated 7%)
#   adding: processed_dataset/train/7/0030.png (deflated 3%)
#   adding: processed_dataset/train/7/0042.png (deflated 12%)
#   adding: processed_dataset/train/7/0019.png (deflated 2%)
#   adding: processed_dataset/train/7/0000.png (stored 0%)
#   adding: processed_dataset/train/7/0020.png (stored 0%)
#   adding: processed_dataset/train/7/0035.png (stored 0%)
#   adding: processed_dataset/train/0/ (stored 0%)
#   adding: processed_dataset/train/0/0024.png (deflated 5%)
#   adding: processed_dataset/train/0/0036.png (deflated 5%)
#   adding: processed_dataset/train/0/0012.png (deflated 17%)
#   adding: processed_dataset/train/0/0059.png (deflated 11%)
#   adding: processed_dataset/train/0/0065.png (deflated 3%)
#   adding: processed_dataset/train/0/0026.png (deflated 17%)
#   adding: processed_dataset/train/0/0014.png (stored 0%)
#   adding: processed_dataset/train/0/0064.png (deflated 7%)
#   adding: processed_dataset/train/0/0063.png (deflated 10%)
#   adding: processed_dataset/train/0/0055.png (deflated 5%)
#   adding: processed_dataset/train/0/0008.png (deflated 9%)
#   adding: processed_dataset/train/0/0002.png (deflated 15%)
#   adding: processed_dataset/train/0/0025.png (deflated 7%)
#   adding: processed_dataset/train/0/0039.png (deflated 9%)
#   adding: processed_dataset/train/0/0015.png (deflated 1%)
#   adding: processed_dataset/train/0/0017.png (deflated 16%)
#   adding: processed_dataset/train/0/0057.png (deflated 3%)
#   adding: processed_dataset/train/0/0001.png (deflated 8%)
#   adding: processed_dataset/train/0/0051.png (deflated 9%)
#   adding: processed_dataset/train/0/0003.png (deflated 13%)
#   adding: processed_dataset/train/0/0004.png (deflated 17%)
#   adding: processed_dataset/train/0/0049.png (deflated 4%)
#   adding: processed_dataset/train/0/0010.png (deflated 6%)
#   adding: processed_dataset/train/0/0007.png (deflated 9%)
#   adding: processed_dataset/train/0/0023.png (deflated 15%)
#   adding: processed_dataset/train/0/0018.png (deflated 5%)
#   adding: processed_dataset/train/0/0009.png (deflated 11%)
#   adding: processed_dataset/train/0/0013.png (deflated 5%)
#   adding: processed_dataset/train/0/0058.png (stored 0%)
#   adding: processed_dataset/train/0/0016.png (deflated 10%)
#   adding: processed_dataset/train/0/0047.png (deflated 21%)
#   adding: processed_dataset/train/0/0045.png (deflated 18%)
#   adding: processed_dataset/train/0/0054.png (deflated 52%)
#   adding: processed_dataset/train/0/0032.png (deflated 4%)
#   adding: processed_dataset/train/0/0027.png (deflated 4%)
#   adding: processed_dataset/train/0/0052.png (stored 0%)
#   adding: processed_dataset/train/0/0043.png (deflated 12%)
#   adding: processed_dataset/train/0/0040.png (deflated 18%)
#   adding: processed_dataset/train/0/0050.png (deflated 8%)
#   adding: processed_dataset/train/0/0046.png (deflated 17%)
#   adding: processed_dataset/train/0/0048.png (deflated 16%)
#   adding: processed_dataset/train/0/0044.png (deflated 13%)
#   adding: processed_dataset/train/0/0041.png (deflated 4%)
#   adding: processed_dataset/train/0/0005.png (deflated 13%)
#   adding: processed_dataset/train/0/0053.png (deflated 15%)
#   adding: processed_dataset/train/0/0011.png (deflated 8%)
#   adding: processed_dataset/train/0/0061.png (deflated 37%)
#   adding: processed_dataset/train/0/0033.png (deflated 13%)
#   adding: processed_dataset/train/0/0038.png (deflated 28%)
#   adding: processed_dataset/train/0/0034.png (stored 0%)
#   adding: processed_dataset/train/0/0006.png (deflated 7%)
#   adding: processed_dataset/train/0/0029.png (deflated 7%)
#   adding: processed_dataset/train/0/0037.png (deflated 9%)
#   adding: processed_dataset/train/0/0021.png (deflated 7%)
#   adding: processed_dataset/train/0/0022.png (deflated 4%)
#   adding: processed_dataset/train/0/0028.png (deflated 9%)
#   adding: processed_dataset/train/0/0062.png (deflated 3%)
#   adding: processed_dataset/train/0/0060.png (deflated 5%)
#   adding: processed_dataset/train/0/0031.png (deflated 4%)
#   adding: processed_dataset/train/0/0056.png (deflated 4%)
#   adding: processed_dataset/train/0/0030.png (deflated 2%)
#   adding: processed_dataset/train/0/0042.png (deflated 18%)
#   adding: processed_dataset/train/0/0019.png (deflated 8%)
#   adding: processed_dataset/train/0/0000.png (deflated 10%)
#   adding: processed_dataset/train/0/0020.png (deflated 15%)
#   adding: processed_dataset/train/0/0035.png (stored 0%)
#   adding: processed_dataset/test_comp/ (stored 0%)
#   adding: processed_dataset/test_comp/E/ (stored 0%)
#   adding: processed_dataset/test_comp/E/0024.png (deflated 17%)
#   adding: processed_dataset/test_comp/E/0012.png (deflated 44%)
#   adding: processed_dataset/test_comp/E/0026.png (deflated 52%)
#   adding: processed_dataset/test_comp/E/0014.png (deflated 14%)
#   adding: processed_dataset/test_comp/E/0008.png (deflated 49%)
#   adding: processed_dataset/test_comp/E/0002.png (deflated 54%)
#   adding: processed_dataset/test_comp/E/0025.png (deflated 36%)
#   adding: processed_dataset/test_comp/E/0015.png (deflated 10%)
#   adding: processed_dataset/test_comp/E/0017.png (deflated 8%)
#   adding: processed_dataset/test_comp/E/0001.png (deflated 31%)
#   adding: processed_dataset/test_comp/E/0003.png (deflated 57%)
#   adding: processed_dataset/test_comp/E/0004.png (deflated 18%)
#   adding: processed_dataset/test_comp/E/0010.png (deflated 30%)
#   adding: processed_dataset/test_comp/E/0007.png (deflated 35%)
#   adding: processed_dataset/test_comp/E/0023.png (deflated 47%)
#   adding: processed_dataset/test_comp/E/0018.png (deflated 53%)
#   adding: processed_dataset/test_comp/E/0009.png (deflated 7%)
#   adding: processed_dataset/test_comp/E/0013.png (deflated 24%)
#   adding: processed_dataset/test_comp/E/0016.png (deflated 8%)
#   adding: processed_dataset/test_comp/E/0027.png (deflated 35%)
#   adding: processed_dataset/test_comp/E/0005.png (deflated 37%)
#   adding: processed_dataset/test_comp/E/0011.png (deflated 20%)
#   adding: processed_dataset/test_comp/E/0006.png (deflated 16%)
#   adding: processed_dataset/test_comp/E/0029.png (deflated 51%)
#   adding: processed_dataset/test_comp/E/0021.png (deflated 35%)
#   adding: processed_dataset/test_comp/E/0022.png (deflated 29%)
#   adding: processed_dataset/test_comp/E/0028.png (deflated 7%)
#   adding: processed_dataset/test_comp/E/0031.png (deflated 29%)
#   adding: processed_dataset/test_comp/E/0030.png (deflated 11%)
#   adding: processed_dataset/test_comp/E/0019.png (deflated 14%)
#   adding: processed_dataset/test_comp/E/0000.png (deflated 24%)
#   adding: processed_dataset/test_comp/E/0020.png (deflated 55%)
#   adding: processed_dataset/test_comp/A/ (stored 0%)
#   adding: processed_dataset/test_comp/A/0024.png (deflated 24%)
#   adding: processed_dataset/test_comp/A/0012.png (deflated 5%)
#   adding: processed_dataset/test_comp/A/0026.png (deflated 19%)
#   adding: processed_dataset/test_comp/A/0014.png (deflated 14%)
#   adding: processed_dataset/test_comp/A/0008.png (deflated 10%)
#   adding: processed_dataset/test_comp/A/0002.png (deflated 9%)
#   adding: processed_dataset/test_comp/A/0025.png (deflated 30%)
#   adding: processed_dataset/test_comp/A/0015.png (deflated 16%)
#   adding: processed_dataset/test_comp/A/0017.png (deflated 3%)
#   adding: processed_dataset/test_comp/A/0001.png (deflated 18%)
#   adding: processed_dataset/test_comp/A/0003.png (deflated 12%)
#   adding: processed_dataset/test_comp/A/0004.png (deflated 11%)
#   adding: processed_dataset/test_comp/A/0010.png (deflated 12%)
#   adding: processed_dataset/test_comp/A/0007.png (deflated 16%)
#   adding: processed_dataset/test_comp/A/0023.png (deflated 12%)
#   adding: processed_dataset/test_comp/A/0018.png (deflated 14%)
#   adding: processed_dataset/test_comp/A/0009.png (deflated 12%)
#   adding: processed_dataset/test_comp/A/0013.png (deflated 17%)
#   adding: processed_dataset/test_comp/A/0016.png (deflated 12%)
#   adding: processed_dataset/test_comp/A/0027.png (deflated 15%)
#   adding: processed_dataset/test_comp/A/0005.png (deflated 8%)
#   adding: processed_dataset/test_comp/A/0011.png (deflated 7%)
#   adding: processed_dataset/test_comp/A/0006.png (deflated 17%)
#   adding: processed_dataset/test_comp/A/0029.png (deflated 13%)
#   adding: processed_dataset/test_comp/A/0021.png (deflated 11%)
#   adding: processed_dataset/test_comp/A/0022.png (deflated 14%)
#   adding: processed_dataset/test_comp/A/0028.png (deflated 9%)
#   adding: processed_dataset/test_comp/A/0030.png (deflated 9%)
#   adding: processed_dataset/test_comp/A/0019.png (deflated 12%)
#   adding: processed_dataset/test_comp/A/0000.png (deflated 8%)
#   adding: processed_dataset/test_comp/A/0020.png (deflated 28%)
#   adding: processed_dataset/test_comp/8/ (stored 0%)
#   adding: processed_dataset/test_comp/8/0024.png (deflated 5%)
#   adding: processed_dataset/test_comp/8/0012.png (deflated 10%)
#   adding: processed_dataset/test_comp/8/0026.png (deflated 20%)
#   adding: processed_dataset/test_comp/8/0014.png (deflated 13%)
#   adding: processed_dataset/test_comp/8/0008.png (deflated 19%)
#   adding: processed_dataset/test_comp/8/0002.png (deflated 10%)
#   adding: processed_dataset/test_comp/8/0025.png (deflated 13%)
#   adding: processed_dataset/test_comp/8/0015.png (deflated 8%)
#   adding: processed_dataset/test_comp/8/0017.png (deflated 9%)
#   adding: processed_dataset/test_comp/8/0001.png (deflated 9%)
#   adding: processed_dataset/test_comp/8/0003.png (deflated 9%)
#   adding: processed_dataset/test_comp/8/0004.png (deflated 13%)
#   adding: processed_dataset/test_comp/8/0010.png (deflated 17%)
#   adding: processed_dataset/test_comp/8/0007.png (deflated 15%)
#   adding: processed_dataset/test_comp/8/0023.png (deflated 5%)
#   adding: processed_dataset/test_comp/8/0018.png (deflated 13%)
#   adding: processed_dataset/test_comp/8/0009.png (deflated 5%)
#   adding: processed_dataset/test_comp/8/0013.png (deflated 13%)
#   adding: processed_dataset/test_comp/8/0016.png (deflated 6%)
#   adding: processed_dataset/test_comp/8/0027.png (deflated 7%)
#   adding: processed_dataset/test_comp/8/0005.png (deflated 8%)
#   adding: processed_dataset/test_comp/8/0011.png (deflated 5%)
#   adding: processed_dataset/test_comp/8/0006.png (deflated 9%)
#   adding: processed_dataset/test_comp/8/0029.png (deflated 8%)
#   adding: processed_dataset/test_comp/8/0021.png (deflated 9%)
#   adding: processed_dataset/test_comp/8/0022.png (deflated 16%)
#   adding: processed_dataset/test_comp/8/0028.png (deflated 15%)
#   adding: processed_dataset/test_comp/8/0031.png (deflated 3%)
#   adding: processed_dataset/test_comp/8/0030.png (deflated 7%)
#   adding: processed_dataset/test_comp/8/0019.png (deflated 16%)
#   adding: processed_dataset/test_comp/8/0000.png (deflated 12%)
#   adding: processed_dataset/test_comp/8/0020.png (deflated 21%)
#   adding: processed_dataset/test_comp/3/ (stored 0%)
#   adding: processed_dataset/test_comp/3/0024.png (deflated 22%)
#   adding: processed_dataset/test_comp/3/0012.png (deflated 8%)
#   adding: processed_dataset/test_comp/3/0026.png (deflated 21%)
#   adding: processed_dataset/test_comp/3/0014.png (deflated 10%)
#   adding: processed_dataset/test_comp/3/0008.png (deflated 13%)
#   adding: processed_dataset/test_comp/3/0002.png (deflated 11%)
#   adding: processed_dataset/test_comp/3/0025.png (deflated 12%)
#   adding: processed_dataset/test_comp/3/0015.png (deflated 13%)
#   adding: processed_dataset/test_comp/3/0017.png (deflated 4%)
#   adding: processed_dataset/test_comp/3/0001.png (deflated 11%)
#   adding: processed_dataset/test_comp/3/0003.png (deflated 7%)
#   adding: processed_dataset/test_comp/3/0004.png (deflated 25%)
#   adding: processed_dataset/test_comp/3/0010.png (deflated 19%)
#   adding: processed_dataset/test_comp/3/0007.png (deflated 18%)
#   adding: processed_dataset/test_comp/3/0023.png (deflated 9%)
#   adding: processed_dataset/test_comp/3/0018.png (deflated 11%)
#   adding: processed_dataset/test_comp/3/0009.png (deflated 7%)
#   adding: processed_dataset/test_comp/3/0013.png (deflated 9%)
#   adding: processed_dataset/test_comp/3/0016.png (deflated 73%)
#   adding: processed_dataset/test_comp/3/0027.png (deflated 13%)
#   adding: processed_dataset/test_comp/3/0005.png (deflated 31%)
#   adding: processed_dataset/test_comp/3/0011.png (deflated 13%)
#   adding: processed_dataset/test_comp/3/0006.png (deflated 5%)
#   adding: processed_dataset/test_comp/3/0029.png (deflated 10%)
#   adding: processed_dataset/test_comp/3/0021.png (deflated 17%)
#   adding: processed_dataset/test_comp/3/0022.png (deflated 13%)
#   adding: processed_dataset/test_comp/3/0028.png (deflated 14%)
#   adding: processed_dataset/test_comp/3/0030.png (deflated 11%)
#   adding: processed_dataset/test_comp/3/0019.png (deflated 21%)
#   adding: processed_dataset/test_comp/3/0000.png (deflated 7%)
#   adding: processed_dataset/test_comp/3/0020.png (deflated 18%)
#   adding: processed_dataset/test_comp/U/ (stored 0%)
#   adding: processed_dataset/test_comp/U/0024.png (deflated 17%)
#   adding: processed_dataset/test_comp/U/0012.png (deflated 36%)
#   adding: processed_dataset/test_comp/U/0026.png (deflated 53%)
#   adding: processed_dataset/test_comp/U/0014.png (deflated 11%)
#   adding: processed_dataset/test_comp/U/0008.png (deflated 34%)
#   adding: processed_dataset/test_comp/U/0002.png (deflated 15%)
#   adding: processed_dataset/test_comp/U/0025.png (deflated 31%)
#   adding: processed_dataset/test_comp/U/0015.png (deflated 20%)
#   adding: processed_dataset/test_comp/U/0017.png (deflated 21%)
#   adding: processed_dataset/test_comp/U/0001.png (deflated 30%)
#   adding: processed_dataset/test_comp/U/0003.png (deflated 29%)
#   adding: processed_dataset/test_comp/U/0004.png (deflated 41%)
#   adding: processed_dataset/test_comp/U/0010.png (deflated 31%)
#   adding: processed_dataset/test_comp/U/0007.png (deflated 43%)
#   adding: processed_dataset/test_comp/U/0023.png (deflated 21%)
#   adding: processed_dataset/test_comp/U/0018.png (deflated 28%)
#   adding: processed_dataset/test_comp/U/0009.png (deflated 19%)
#   adding: processed_dataset/test_comp/U/0013.png (deflated 24%)
#   adding: processed_dataset/test_comp/U/0016.png (deflated 5%)
#   adding: processed_dataset/test_comp/U/0027.png (deflated 25%)
#   adding: processed_dataset/test_comp/U/0005.png (deflated 50%)
#   adding: processed_dataset/test_comp/U/0011.png (deflated 24%)
#   adding: processed_dataset/test_comp/U/0006.png (deflated 33%)
#   adding: processed_dataset/test_comp/U/0029.png (deflated 18%)
#   adding: processed_dataset/test_comp/U/0021.png (deflated 28%)
#   adding: processed_dataset/test_comp/U/0022.png (deflated 39%)
#   adding: processed_dataset/test_comp/U/0028.png (deflated 73%)
#   adding: processed_dataset/test_comp/U/0031.png (deflated 16%)
#   adding: processed_dataset/test_comp/U/0030.png (deflated 13%)
#   adding: processed_dataset/test_comp/U/0019.png (deflated 39%)
#   adding: processed_dataset/test_comp/U/0000.png (deflated 27%)
#   adding: processed_dataset/test_comp/U/0020.png (deflated 27%)
#   adding: processed_dataset/test_comp/R/ (stored 0%)
#   adding: processed_dataset/test_comp/R/0024.png (deflated 22%)
#   adding: processed_dataset/test_comp/R/0012.png (deflated 21%)
#   adding: processed_dataset/test_comp/R/0026.png (deflated 16%)
#   adding: processed_dataset/test_comp/R/0014.png (deflated 8%)
#   adding: processed_dataset/test_comp/R/0008.png (deflated 31%)
#   adding: processed_dataset/test_comp/R/0002.png (deflated 15%)
#   adding: processed_dataset/test_comp/R/0025.png (deflated 38%)
#   adding: processed_dataset/test_comp/R/0015.png (deflated 19%)
#   adding: processed_dataset/test_comp/R/0017.png (deflated 5%)
#   adding: processed_dataset/test_comp/R/0001.png (deflated 17%)
#   adding: processed_dataset/test_comp/R/0003.png (deflated 31%)
#   adding: processed_dataset/test_comp/R/0004.png (deflated 51%)
#   adding: processed_dataset/test_comp/R/0010.png (deflated 23%)
#   adding: processed_dataset/test_comp/R/0007.png (deflated 21%)
#   adding: processed_dataset/test_comp/R/0023.png (deflated 18%)
#   adding: processed_dataset/test_comp/R/0018.png (deflated 12%)
#   adding: processed_dataset/test_comp/R/0009.png (deflated 8%)
#   adding: processed_dataset/test_comp/R/0013.png (deflated 11%)
#   adding: processed_dataset/test_comp/R/0016.png (deflated 19%)
#   adding: processed_dataset/test_comp/R/0032.png (deflated 10%)
#   adding: processed_dataset/test_comp/R/0027.png (deflated 30%)
#   adding: processed_dataset/test_comp/R/0005.png (deflated 21%)
#   adding: processed_dataset/test_comp/R/0011.png (deflated 9%)
#   adding: processed_dataset/test_comp/R/0006.png (deflated 14%)
#   adding: processed_dataset/test_comp/R/0029.png (deflated 29%)
#   adding: processed_dataset/test_comp/R/0021.png (deflated 21%)
#   adding: processed_dataset/test_comp/R/0022.png (deflated 11%)
#   adding: processed_dataset/test_comp/R/0028.png (deflated 5%)
#   adding: processed_dataset/test_comp/R/0031.png (deflated 21%)
#   adding: processed_dataset/test_comp/R/0030.png (deflated 16%)
#   adding: processed_dataset/test_comp/R/0019.png (deflated 18%)
#   adding: processed_dataset/test_comp/R/0000.png (deflated 17%)
#   adding: processed_dataset/test_comp/R/0020.png (deflated 27%)
#   adding: processed_dataset/test_comp/V/ (stored 0%)
#   adding: processed_dataset/test_comp/V/0024.png (deflated 15%)
#   adding: processed_dataset/test_comp/V/0012.png (deflated 10%)
#   adding: processed_dataset/test_comp/V/0026.png (deflated 10%)
#   adding: processed_dataset/test_comp/V/0014.png (deflated 21%)
#   adding: processed_dataset/test_comp/V/0008.png (deflated 12%)
#   adding: processed_dataset/test_comp/V/0002.png (deflated 12%)
#   adding: processed_dataset/test_comp/V/0025.png (deflated 9%)
#   adding: processed_dataset/test_comp/V/0015.png (deflated 15%)
#   adding: processed_dataset/test_comp/V/0017.png (deflated 4%)
#   adding: processed_dataset/test_comp/V/0001.png (deflated 15%)
#   adding: processed_dataset/test_comp/V/0003.png (deflated 30%)
#   adding: processed_dataset/test_comp/V/0004.png (deflated 12%)
#   adding: processed_dataset/test_comp/V/0010.png (deflated 14%)
#   adding: processed_dataset/test_comp/V/0007.png (deflated 34%)
#   adding: processed_dataset/test_comp/V/0023.png (deflated 16%)
#   adding: processed_dataset/test_comp/V/0018.png (deflated 7%)
#   adding: processed_dataset/test_comp/V/0009.png (deflated 10%)
#   adding: processed_dataset/test_comp/V/0013.png (deflated 17%)
#   adding: processed_dataset/test_comp/V/0016.png (deflated 20%)
#   adding: processed_dataset/test_comp/V/0032.png (deflated 4%)
#   adding: processed_dataset/test_comp/V/0027.png (deflated 21%)
#   adding: processed_dataset/test_comp/V/0005.png (deflated 11%)
#   adding: processed_dataset/test_comp/V/0011.png (deflated 3%)
#   adding: processed_dataset/test_comp/V/0006.png (deflated 12%)
#   adding: processed_dataset/test_comp/V/0029.png (deflated 27%)
#   adding: processed_dataset/test_comp/V/0021.png (deflated 19%)
#   adding: processed_dataset/test_comp/V/0022.png (deflated 13%)
#   adding: processed_dataset/test_comp/V/0028.png (deflated 7%)
#   adding: processed_dataset/test_comp/V/0031.png (deflated 17%)
#   adding: processed_dataset/test_comp/V/0030.png (deflated 15%)
#   adding: processed_dataset/test_comp/V/0019.png (deflated 19%)
#   adding: processed_dataset/test_comp/V/0000.png (deflated 9%)
#   adding: processed_dataset/test_comp/V/0020.png (deflated 11%)
#   adding: processed_dataset/test_comp/5/ (stored 0%)
#   adding: processed_dataset/test_comp/5/0024.png (deflated 11%)
#   adding: processed_dataset/test_comp/5/0012.png (deflated 23%)
#   adding: processed_dataset/test_comp/5/0026.png (deflated 8%)
#   adding: processed_dataset/test_comp/5/0014.png (deflated 18%)
#   adding: processed_dataset/test_comp/5/0008.png (deflated 15%)
#   adding: processed_dataset/test_comp/5/0002.png (deflated 12%)
#   adding: processed_dataset/test_comp/5/0025.png (deflated 10%)
#   adding: processed_dataset/test_comp/5/0015.png (deflated 12%)
#   adding: processed_dataset/test_comp/5/0017.png (deflated 5%)
#   adding: processed_dataset/test_comp/5/0001.png (deflated 15%)
#   adding: processed_dataset/test_comp/5/0003.png (deflated 8%)
#   adding: processed_dataset/test_comp/5/0004.png (deflated 28%)
#   adding: processed_dataset/test_comp/5/0010.png (deflated 22%)
#   adding: processed_dataset/test_comp/5/0007.png (deflated 25%)
#   adding: processed_dataset/test_comp/5/0023.png (deflated 24%)
#   adding: processed_dataset/test_comp/5/0018.png (deflated 8%)
#   adding: processed_dataset/test_comp/5/0009.png (deflated 11%)
#   adding: processed_dataset/test_comp/5/0013.png (deflated 10%)
#   adding: processed_dataset/test_comp/5/0016.png (deflated 19%)
#   adding: processed_dataset/test_comp/5/0032.png (deflated 23%)
#   adding: processed_dataset/test_comp/5/0027.png (deflated 50%)
#   adding: processed_dataset/test_comp/5/0005.png (deflated 22%)
#   adding: processed_dataset/test_comp/5/0011.png (deflated 3%)
#   adding: processed_dataset/test_comp/5/0006.png (deflated 7%)
#   adding: processed_dataset/test_comp/5/0029.png (deflated 33%)
#   adding: processed_dataset/test_comp/5/0021.png (deflated 28%)
#   adding: processed_dataset/test_comp/5/0022.png (deflated 18%)
#   adding: processed_dataset/test_comp/5/0028.png (deflated 24%)
#   adding: processed_dataset/test_comp/5/0031.png (deflated 23%)
#   adding: processed_dataset/test_comp/5/0030.png (deflated 7%)
#   adding: processed_dataset/test_comp/5/0019.png (deflated 5%)
#   adding: processed_dataset/test_comp/5/0000.png (deflated 14%)
#   adding: processed_dataset/test_comp/5/0020.png (deflated 31%)
#   adding: processed_dataset/test_comp/Q/ (stored 0%)
#   adding: processed_dataset/test_comp/Q/0024.png (deflated 13%)
#   adding: processed_dataset/test_comp/Q/0012.png (deflated 12%)
#   adding: processed_dataset/test_comp/Q/0026.png (deflated 3%)
#   adding: processed_dataset/test_comp/Q/0014.png (deflated 11%)
#   adding: processed_dataset/test_comp/Q/0008.png (deflated 10%)
#   adding: processed_dataset/test_comp/Q/0002.png (deflated 20%)
#   adding: processed_dataset/test_comp/Q/0025.png (deflated 51%)
#   adding: processed_dataset/test_comp/Q/0015.png (deflated 4%)
#   adding: processed_dataset/test_comp/Q/0017.png (deflated 15%)
#   adding: processed_dataset/test_comp/Q/0001.png (deflated 22%)
#   adding: processed_dataset/test_comp/Q/0003.png (deflated 32%)
#   adding: processed_dataset/test_comp/Q/0004.png (deflated 18%)
#   adding: processed_dataset/test_comp/Q/0010.png (deflated 8%)
#   adding: processed_dataset/test_comp/Q/0007.png (deflated 21%)
#   adding: processed_dataset/test_comp/Q/0023.png (deflated 10%)
#   adding: processed_dataset/test_comp/Q/0018.png (deflated 12%)
#   adding: processed_dataset/test_comp/Q/0009.png (deflated 20%)
#   adding: processed_dataset/test_comp/Q/0013.png (deflated 33%)
#   adding: processed_dataset/test_comp/Q/0016.png (deflated 9%)
#   adding: processed_dataset/test_comp/Q/0027.png (deflated 28%)
#   adding: processed_dataset/test_comp/Q/0005.png (deflated 15%)
#   adding: processed_dataset/test_comp/Q/0011.png (deflated 11%)
#   adding: processed_dataset/test_comp/Q/0006.png (deflated 17%)
#   adding: processed_dataset/test_comp/Q/0029.png (deflated 13%)
#   adding: processed_dataset/test_comp/Q/0021.png (deflated 12%)
#   adding: processed_dataset/test_comp/Q/0022.png (deflated 13%)
#   adding: processed_dataset/test_comp/Q/0028.png (deflated 15%)
#   adding: processed_dataset/test_comp/Q/0030.png (deflated 4%)
#   adding: processed_dataset/test_comp/Q/0019.png (deflated 18%)
#   adding: processed_dataset/test_comp/Q/0000.png (deflated 16%)
#   adding: processed_dataset/test_comp/Q/0020.png (deflated 11%)
#   adding: processed_dataset/test_comp/O/ (stored 0%)
#   adding: processed_dataset/test_comp/O/0024.png (deflated 24%)
#   adding: processed_dataset/test_comp/O/0012.png (deflated 17%)
#   adding: processed_dataset/test_comp/O/0026.png (deflated 13%)
#   adding: processed_dataset/test_comp/O/0014.png (deflated 8%)
#   adding: processed_dataset/test_comp/O/0008.png (deflated 7%)
#   adding: processed_dataset/test_comp/O/0002.png (deflated 12%)
#   adding: processed_dataset/test_comp/O/0025.png (deflated 5%)
#   adding: processed_dataset/test_comp/O/0015.png (deflated 5%)
#   adding: processed_dataset/test_comp/O/0017.png (deflated 21%)
#   adding: processed_dataset/test_comp/O/0001.png (deflated 7%)
#   adding: processed_dataset/test_comp/O/0003.png (deflated 25%)
#   adding: processed_dataset/test_comp/O/0004.png (deflated 8%)
#   adding: processed_dataset/test_comp/O/0010.png (deflated 7%)
#   adding: processed_dataset/test_comp/O/0007.png (deflated 23%)
#   adding: processed_dataset/test_comp/O/0023.png (deflated 10%)
#   adding: processed_dataset/test_comp/O/0018.png (deflated 29%)
#   adding: processed_dataset/test_comp/O/0009.png (deflated 27%)
#   adding: processed_dataset/test_comp/O/0013.png (deflated 13%)
#   adding: processed_dataset/test_comp/O/0016.png (deflated 18%)
#   adding: processed_dataset/test_comp/O/0027.png (deflated 22%)
#   adding: processed_dataset/test_comp/O/0005.png (deflated 20%)
#   adding: processed_dataset/test_comp/O/0011.png (deflated 14%)
#   adding: processed_dataset/test_comp/O/0006.png (deflated 21%)
#   adding: processed_dataset/test_comp/O/0029.png (deflated 7%)
#   adding: processed_dataset/test_comp/O/0021.png (deflated 5%)
#   adding: processed_dataset/test_comp/O/0022.png (deflated 16%)
#   adding: processed_dataset/test_comp/O/0028.png (deflated 14%)
#   adding: processed_dataset/test_comp/O/0019.png (deflated 13%)
#   adding: processed_dataset/test_comp/O/0000.png (deflated 21%)
#   adding: processed_dataset/test_comp/O/0020.png (deflated 22%)
#   adding: processed_dataset/test_comp/M/ (stored 0%)
#   adding: processed_dataset/test_comp/M/0024.png (deflated 10%)
#   adding: processed_dataset/test_comp/M/0012.png (deflated 19%)
#   adding: processed_dataset/test_comp/M/0026.png (deflated 13%)
#   adding: processed_dataset/test_comp/M/0014.png (deflated 27%)
#   adding: processed_dataset/test_comp/M/0008.png (deflated 37%)
#   adding: processed_dataset/test_comp/M/0002.png (deflated 17%)
#   adding: processed_dataset/test_comp/M/0025.png (deflated 36%)
#   adding: processed_dataset/test_comp/M/0015.png (deflated 26%)
#   adding: processed_dataset/test_comp/M/0017.png (deflated 6%)
#   adding: processed_dataset/test_comp/M/0001.png (deflated 12%)
#   adding: processed_dataset/test_comp/M/0003.png (deflated 29%)
#   adding: processed_dataset/test_comp/M/0004.png (deflated 33%)
#   adding: processed_dataset/test_comp/M/0010.png (deflated 18%)
#   adding: processed_dataset/test_comp/M/0007.png (deflated 19%)
#   adding: processed_dataset/test_comp/M/0023.png (deflated 17%)
#   adding: processed_dataset/test_comp/M/0018.png (deflated 29%)
#   adding: processed_dataset/test_comp/M/0009.png (deflated 23%)
#   adding: processed_dataset/test_comp/M/0013.png (deflated 28%)
#   adding: processed_dataset/test_comp/M/0016.png (deflated 22%)
#   adding: processed_dataset/test_comp/M/0032.png (deflated 13%)
#   adding: processed_dataset/test_comp/M/0027.png (deflated 22%)
#   adding: processed_dataset/test_comp/M/0005.png (deflated 37%)
#   adding: processed_dataset/test_comp/M/0011.png (deflated 26%)
#   adding: processed_dataset/test_comp/M/0006.png (deflated 16%)
#   adding: processed_dataset/test_comp/M/0029.png (deflated 16%)
#   adding: processed_dataset/test_comp/M/0021.png (deflated 30%)
#   adding: processed_dataset/test_comp/M/0022.png (deflated 14%)
#   adding: processed_dataset/test_comp/M/0028.png (deflated 20%)
#   adding: processed_dataset/test_comp/M/0031.png (deflated 20%)
#   adding: processed_dataset/test_comp/M/0030.png (deflated 17%)
#   adding: processed_dataset/test_comp/M/0019.png (deflated 27%)
#   adding: processed_dataset/test_comp/M/0000.png (deflated 29%)
#   adding: processed_dataset/test_comp/M/0020.png (deflated 17%)
#   adding: processed_dataset/test_comp/D/ (stored 0%)
#   adding: processed_dataset/test_comp/D/0024.png (deflated 30%)
#   adding: processed_dataset/test_comp/D/0012.png (deflated 8%)
#   adding: processed_dataset/test_comp/D/0026.png (deflated 46%)
#   adding: processed_dataset/test_comp/D/0014.png (deflated 10%)
#   adding: processed_dataset/test_comp/D/0008.png (deflated 31%)
#   adding: processed_dataset/test_comp/D/0002.png (deflated 18%)
#   adding: processed_dataset/test_comp/D/0025.png (deflated 17%)
#   adding: processed_dataset/test_comp/D/0015.png (deflated 21%)
#   adding: processed_dataset/test_comp/D/0017.png (deflated 9%)
#   adding: processed_dataset/test_comp/D/0001.png (deflated 17%)
#   adding: processed_dataset/test_comp/D/0003.png (deflated 33%)
#   adding: processed_dataset/test_comp/D/0004.png (deflated 46%)
#   adding: processed_dataset/test_comp/D/0010.png (deflated 21%)
#   adding: processed_dataset/test_comp/D/0007.png (deflated 16%)
#   adding: processed_dataset/test_comp/D/0023.png (deflated 22%)
#   adding: processed_dataset/test_comp/D/0018.png (deflated 22%)
#   adding: processed_dataset/test_comp/D/0009.png (deflated 9%)
#   adding: processed_dataset/test_comp/D/0013.png (deflated 21%)
#   adding: processed_dataset/test_comp/D/0016.png (deflated 29%)
#   adding: processed_dataset/test_comp/D/0027.png (deflated 15%)
#   adding: processed_dataset/test_comp/D/0005.png (deflated 30%)
#   adding: processed_dataset/test_comp/D/0011.png (deflated 17%)
#   adding: processed_dataset/test_comp/D/0006.png (deflated 23%)
#   adding: processed_dataset/test_comp/D/0029.png (deflated 27%)
#   adding: processed_dataset/test_comp/D/0021.png (deflated 16%)
#   adding: processed_dataset/test_comp/D/0022.png (deflated 26%)
#   adding: processed_dataset/test_comp/D/0028.png (deflated 21%)
#   adding: processed_dataset/test_comp/D/0030.png (deflated 5%)
#   adding: processed_dataset/test_comp/D/0019.png (deflated 27%)
#   adding: processed_dataset/test_comp/D/0000.png (deflated 19%)
#   adding: processed_dataset/test_comp/D/0020.png (deflated 23%)
#   adding: processed_dataset/test_comp/K/ (stored 0%)
#   adding: processed_dataset/test_comp/K/0024.png (deflated 15%)
#   adding: processed_dataset/test_comp/K/0012.png (deflated 9%)
#   adding: processed_dataset/test_comp/K/0026.png (deflated 28%)
#   adding: processed_dataset/test_comp/K/0014.png (deflated 12%)
#   adding: processed_dataset/test_comp/K/0008.png (deflated 18%)
#   adding: processed_dataset/test_comp/K/0002.png (deflated 15%)
#   adding: processed_dataset/test_comp/K/0025.png (deflated 10%)
#   adding: processed_dataset/test_comp/K/0015.png (deflated 19%)
#   adding: processed_dataset/test_comp/K/0017.png (deflated 8%)
#   adding: processed_dataset/test_comp/K/0001.png (deflated 11%)
#   adding: processed_dataset/test_comp/K/0003.png (deflated 20%)
#   adding: processed_dataset/test_comp/K/0004.png (deflated 22%)
#   adding: processed_dataset/test_comp/K/0010.png (deflated 12%)
#   adding: processed_dataset/test_comp/K/0007.png (deflated 20%)
#   adding: processed_dataset/test_comp/K/0023.png (deflated 23%)
#   adding: processed_dataset/test_comp/K/0018.png (deflated 10%)
#   adding: processed_dataset/test_comp/K/0009.png (deflated 6%)
#   adding: processed_dataset/test_comp/K/0013.png (deflated 11%)
#   adding: processed_dataset/test_comp/K/0016.png (deflated 8%)
#   adding: processed_dataset/test_comp/K/0027.png (deflated 12%)
#   adding: processed_dataset/test_comp/K/0005.png (deflated 24%)
#   adding: processed_dataset/test_comp/K/0011.png (deflated 5%)
#   adding: processed_dataset/test_comp/K/0006.png (deflated 29%)
#   adding: processed_dataset/test_comp/K/0029.png (deflated 21%)
#   adding: processed_dataset/test_comp/K/0021.png (deflated 32%)
#   adding: processed_dataset/test_comp/K/0022.png (deflated 8%)
#   adding: processed_dataset/test_comp/K/0028.png (deflated 10%)
#   adding: processed_dataset/test_comp/K/0031.png (deflated 21%)
#   adding: processed_dataset/test_comp/K/0030.png (deflated 14%)
#   adding: processed_dataset/test_comp/K/0019.png (deflated 8%)
#   adding: processed_dataset/test_comp/K/0000.png (deflated 13%)
#   adding: processed_dataset/test_comp/K/0020.png (deflated 13%)
#   adding: processed_dataset/test_comp/T/ (stored 0%)
#   adding: processed_dataset/test_comp/T/0024.png (deflated 56%)
#   adding: processed_dataset/test_comp/T/0012.png (deflated 21%)
#   adding: processed_dataset/test_comp/T/0026.png (deflated 61%)
#   adding: processed_dataset/test_comp/T/0014.png (deflated 34%)
#   adding: processed_dataset/test_comp/T/0008.png (deflated 43%)
#   adding: processed_dataset/test_comp/T/0002.png (deflated 72%)
#   adding: processed_dataset/test_comp/T/0025.png (deflated 48%)
#   adding: processed_dataset/test_comp/T/0015.png (deflated 71%)
#   adding: processed_dataset/test_comp/T/0017.png (deflated 51%)
#   adding: processed_dataset/test_comp/T/0001.png (deflated 33%)
#   adding: processed_dataset/test_comp/T/0003.png (deflated 54%)
#   adding: processed_dataset/test_comp/T/0004.png (deflated 74%)
#   adding: processed_dataset/test_comp/T/0010.png (deflated 57%)
#   adding: processed_dataset/test_comp/T/0007.png (deflated 67%)
#   adding: processed_dataset/test_comp/T/0023.png (deflated 46%)
#   adding: processed_dataset/test_comp/T/0018.png (deflated 46%)
#   adding: processed_dataset/test_comp/T/0009.png (deflated 59%)
#   adding: processed_dataset/test_comp/T/0013.png (deflated 16%)
#   adding: processed_dataset/test_comp/T/0016.png (deflated 31%)
#   adding: processed_dataset/test_comp/T/0027.png (deflated 18%)
#   adding: processed_dataset/test_comp/T/0005.png (deflated 19%)
#   adding: processed_dataset/test_comp/T/0011.png (deflated 65%)
#   adding: processed_dataset/test_comp/T/0006.png (deflated 60%)
#   adding: processed_dataset/test_comp/T/0029.png (deflated 52%)
#   adding: processed_dataset/test_comp/T/0021.png (deflated 11%)
#   adding: processed_dataset/test_comp/T/0022.png (deflated 62%)
#   adding: processed_dataset/test_comp/T/0028.png (deflated 30%)
#   adding: processed_dataset/test_comp/T/0031.png (deflated 5%)
#   adding: processed_dataset/test_comp/T/0030.png (deflated 51%)
#   adding: processed_dataset/test_comp/T/0019.png (deflated 62%)
#   adding: processed_dataset/test_comp/T/0000.png (deflated 39%)
#   adding: processed_dataset/test_comp/T/0020.png (deflated 31%)
#   adding: processed_dataset/test_comp/J/ (stored 0%)
#   adding: processed_dataset/test_comp/J/0024.png (deflated 30%)
#   adding: processed_dataset/test_comp/J/0012.png (deflated 34%)
#   adding: processed_dataset/test_comp/J/0026.png (deflated 58%)
#   adding: processed_dataset/test_comp/J/0014.png (deflated 12%)
#   adding: processed_dataset/test_comp/J/0008.png (deflated 39%)
#   adding: processed_dataset/test_comp/J/0002.png (deflated 28%)
#   adding: processed_dataset/test_comp/J/0025.png (deflated 57%)
#   adding: processed_dataset/test_comp/J/0015.png (deflated 14%)
#   adding: processed_dataset/test_comp/J/0017.png (deflated 6%)
#   adding: processed_dataset/test_comp/J/0001.png (deflated 31%)
#   adding: processed_dataset/test_comp/J/0003.png (deflated 39%)
#   adding: processed_dataset/test_comp/J/0004.png (deflated 34%)
#   adding: processed_dataset/test_comp/J/0010.png (deflated 35%)
#   adding: processed_dataset/test_comp/J/0007.png (deflated 24%)
#   adding: processed_dataset/test_comp/J/0023.png (deflated 17%)
#   adding: processed_dataset/test_comp/J/0018.png (deflated 36%)
#   adding: processed_dataset/test_comp/J/0009.png (deflated 7%)
#   adding: processed_dataset/test_comp/J/0013.png (deflated 21%)
#   adding: processed_dataset/test_comp/J/0016.png (deflated 73%)
#   adding: processed_dataset/test_comp/J/0027.png (deflated 32%)
#   adding: processed_dataset/test_comp/J/0005.png (deflated 41%)
#   adding: processed_dataset/test_comp/J/0011.png (deflated 11%)
#   adding: processed_dataset/test_comp/J/0006.png (deflated 27%)
#   adding: processed_dataset/test_comp/J/0029.png (deflated 51%)
#   adding: processed_dataset/test_comp/J/0021.png (deflated 36%)
#   adding: processed_dataset/test_comp/J/0022.png (deflated 25%)
#   adding: processed_dataset/test_comp/J/0028.png (deflated 59%)
#   adding: processed_dataset/test_comp/J/0030.png (deflated 29%)
#   adding: processed_dataset/test_comp/J/0019.png (deflated 41%)
#   adding: processed_dataset/test_comp/J/0000.png (deflated 32%)
#   adding: processed_dataset/test_comp/J/0020.png (deflated 42%)
#   adding: processed_dataset/test_comp/I/ (stored 0%)
#   adding: processed_dataset/test_comp/I/0024.png (deflated 26%)
#   adding: processed_dataset/test_comp/I/0012.png (deflated 59%)
#   adding: processed_dataset/test_comp/I/0026.png (deflated 73%)
#   adding: processed_dataset/test_comp/I/0014.png (deflated 10%)
#   adding: processed_dataset/test_comp/I/0008.png (deflated 53%)
#   adding: processed_dataset/test_comp/I/0002.png (deflated 66%)
#   adding: processed_dataset/test_comp/I/0025.png (deflated 41%)
#   adding: processed_dataset/test_comp/I/0015.png (deflated 61%)
#   adding: processed_dataset/test_comp/I/0017.png (deflated 14%)
#   adding: processed_dataset/test_comp/I/0001.png (deflated 68%)
#   adding: processed_dataset/test_comp/I/0003.png (deflated 40%)
#   adding: processed_dataset/test_comp/I/0004.png (deflated 38%)
#   adding: processed_dataset/test_comp/I/0010.png (deflated 22%)
#   adding: processed_dataset/test_comp/I/0007.png (deflated 57%)
#   adding: processed_dataset/test_comp/I/0023.png (deflated 42%)
#   adding: processed_dataset/test_comp/I/0018.png (deflated 44%)
#   adding: processed_dataset/test_comp/I/0009.png (deflated 16%)
#   adding: processed_dataset/test_comp/I/0013.png (deflated 13%)
#   adding: processed_dataset/test_comp/I/0016.png (deflated 44%)
#   adding: processed_dataset/test_comp/I/0027.png (deflated 25%)
#   adding: processed_dataset/test_comp/I/0005.png (deflated 79%)
#   adding: processed_dataset/test_comp/I/0011.png (deflated 23%)
#   adding: processed_dataset/test_comp/I/0006.png (deflated 34%)
#   adding: processed_dataset/test_comp/I/0029.png (deflated 74%)
#   adding: processed_dataset/test_comp/I/0021.png (deflated 59%)
#   adding: processed_dataset/test_comp/I/0022.png (deflated 31%)
# ...
#   adding: processed_dataset/train_comp/X/0004.png (deflated 4%)
#   adding: processed_dataset/train_comp/X/0049.png (deflated 23%)
#   adding: processed_dataset/train_comp/X/0010.png (deflated 9%)
#   adding: processed_dataset/train_comp/X/0007.png (deflated 10%)
#   adding: processed_dataset/train_comp/X/0023.png (deflated 7%)
#   adding: processed_dataset/train_comp/X/0018.png (deflated 12%)
#   adding: processed_dataset/train_comp/X/0009.png (deflated 7%)
#   adding: processed_dataset/train_comp/X/0013.png (deflated 9%)
#   adding: processed_dataset/train_comp/X/0058.png (deflated 9%)
#   adding: processed_dataset/train_comp/X/0016.png (deflated 14%)
#   adding: processed_dataset/train_comp/X/0047.png (deflated 7%)
#   adding: processed_dataset/train_comp/X/0045.png (deflated 16%)
#   adding: processed_dataset/train_comp/X/0054.png (deflated 26%)
#   adding: processed_dataset/train_comp/X/0032.png (deflated 12%)
#   adding: processed_dataset/train_comp/X/0027.png (deflated 9%)
#   adding: processed_dataset/train_comp/X/0052.png (deflated 8%)
#   adding: processed_dataset/train_comp/X/0043.png (deflated 7%)
#   adding: processed_dataset/train_comp/X/0040.png (deflated 26%)
#   adding: processed_dataset/train_comp/X/0050.png (deflated 55%)
#   adding: processed_dataset/train_comp/X/0046.png (deflated 8%)
#   adding: processed_dataset/train_comp/X/0048.png (deflated 11%)
#   adding: processed_dataset/train_comp/X/0044.png (deflated 17%)
#   adding: processed_dataset/train_comp/X/0041.png (deflated 23%)
#   adding: processed_dataset/train_comp/X/0005.png (deflated 8%)
#   adding: processed_dataset/train_comp/X/0053.png (deflated 15%)
#   adding: processed_dataset/train_comp/X/0011.png (deflated 17%)
#   adding: processed_dataset/train_comp/X/0033.png (deflated 4%)
#   adding: processed_dataset/train_comp/X/0038.png (deflated 3%)
#   adding: processed_dataset/train_comp/X/0034.png (deflated 4%)
#   adding: processed_dataset/train_comp/X/0006.png (deflated 5%)
#   adding: processed_dataset/train_comp/X/0029.png (deflated 7%)
#   adding: processed_dataset/train_comp/X/0037.png (deflated 12%)
#   adding: processed_dataset/train_comp/X/0021.png (deflated 8%)
#   adding: processed_dataset/train_comp/X/0022.png (deflated 14%)
#   adding: processed_dataset/train_comp/X/0028.png (deflated 8%)
#   adding: processed_dataset/train_comp/X/0060.png (deflated 4%)
#   adding: processed_dataset/train_comp/X/0031.png (deflated 5%)
#   adding: processed_dataset/train_comp/X/0056.png (deflated 8%)
#   adding: processed_dataset/train_comp/X/0030.png (deflated 13%)
#   adding: processed_dataset/train_comp/X/0042.png (deflated 8%)
#   adding: processed_dataset/train_comp/X/0019.png (deflated 8%)
#   adding: processed_dataset/train_comp/X/0000.png (deflated 13%)
#   adding: processed_dataset/train_comp/X/0020.png (deflated 11%)
#   adding: processed_dataset/train_comp/X/0035.png (deflated 9%)
#   adding: processed_dataset/train_comp/4/ (stored 0%)
#   adding: processed_dataset/train_comp/4/0024.png (deflated 39%)
#   adding: processed_dataset/train_comp/4/0036.png (deflated 16%)
#   adding: processed_dataset/train_comp/4/0012.png (deflated 17%)
#   adding: processed_dataset/train_comp/4/0059.png (deflated 47%)
#   adding: processed_dataset/train_comp/4/0065.png (deflated 18%)
#   adding: processed_dataset/train_comp/4/0026.png (deflated 22%)
#   adding: processed_dataset/train_comp/4/0014.png (deflated 35%)
#   adding: processed_dataset/train_comp/4/0064.png (deflated 23%)
#   adding: processed_dataset/train_comp/4/0063.png (deflated 31%)
#   adding: processed_dataset/train_comp/4/0055.png (deflated 26%)
#   adding: processed_dataset/train_comp/4/0008.png (deflated 13%)
#   adding: processed_dataset/train_comp/4/0002.png (deflated 42%)
#   adding: processed_dataset/train_comp/4/0025.png (deflated 46%)
#   adding: processed_dataset/train_comp/4/0039.png (deflated 33%)
#   adding: processed_dataset/train_comp/4/0015.png (deflated 31%)
#   adding: processed_dataset/train_comp/4/0017.png (deflated 32%)
#   adding: processed_dataset/train_comp/4/0057.png (deflated 30%)
#   adding: processed_dataset/train_comp/4/0066.png (deflated 20%)
#   adding: processed_dataset/train_comp/4/0001.png (deflated 19%)
#   adding: processed_dataset/train_comp/4/0051.png (deflated 38%)
#   adding: processed_dataset/train_comp/4/0003.png (deflated 23%)
#   adding: processed_dataset/train_comp/4/0004.png (deflated 23%)
#   adding: processed_dataset/train_comp/4/0049.png (deflated 16%)
#   adding: processed_dataset/train_comp/4/0010.png (deflated 25%)
#   adding: processed_dataset/train_comp/4/0007.png (deflated 37%)
#   adding: processed_dataset/train_comp/4/0023.png (deflated 5%)
#   adding: processed_dataset/train_comp/4/0018.png (deflated 32%)
#   adding: processed_dataset/train_comp/4/0009.png (deflated 35%)
#   adding: processed_dataset/train_comp/4/0013.png (deflated 23%)
#   adding: processed_dataset/train_comp/4/0058.png (deflated 23%)
#   adding: processed_dataset/train_comp/4/0016.png (deflated 24%)
#   adding: processed_dataset/train_comp/4/0047.png (deflated 36%)
#   adding: processed_dataset/train_comp/4/0045.png (deflated 11%)
#   adding: processed_dataset/train_comp/4/0054.png (deflated 26%)
#   adding: processed_dataset/train_comp/4/0032.png (deflated 35%)
#   adding: processed_dataset/train_comp/4/0027.png (deflated 18%)
#   adding: processed_dataset/train_comp/4/0052.png (deflated 32%)
#   adding: processed_dataset/train_comp/4/0043.png (deflated 32%)
#   adding: processed_dataset/train_comp/4/0040.png (deflated 36%)
#   adding: processed_dataset/train_comp/4/0050.png (deflated 21%)
#   adding: processed_dataset/train_comp/4/0046.png (deflated 45%)
#   adding: processed_dataset/train_comp/4/0048.png (deflated 29%)
#   adding: processed_dataset/train_comp/4/0044.png (deflated 10%)
#   adding: processed_dataset/train_comp/4/0041.png (deflated 36%)
#   adding: processed_dataset/train_comp/4/0005.png (deflated 19%)
#   adding: processed_dataset/train_comp/4/0053.png (deflated 24%)
#   adding: processed_dataset/train_comp/4/0011.png (deflated 15%)
#   adding: processed_dataset/train_comp/4/0061.png (deflated 8%)
#   adding: processed_dataset/train_comp/4/0033.png (deflated 13%)
#   adding: processed_dataset/train_comp/4/0038.png (deflated 25%)
#   adding: processed_dataset/train_comp/4/0034.png (deflated 4%)
#   adding: processed_dataset/train_comp/4/0006.png (deflated 48%)
#   adding: processed_dataset/train_comp/4/0029.png (deflated 13%)
#   adding: processed_dataset/train_comp/4/0037.png (deflated 23%)
#   adding: processed_dataset/train_comp/4/0021.png (deflated 39%)
#   adding: processed_dataset/train_comp/4/0022.png (deflated 8%)
#   adding: processed_dataset/train_comp/4/0028.png (deflated 9%)
#   adding: processed_dataset/train_comp/4/0062.png (deflated 20%)
#   adding: processed_dataset/train_comp/4/0060.png (deflated 41%)
#   adding: processed_dataset/train_comp/4/0031.png (deflated 7%)
#   adding: processed_dataset/train_comp/4/0056.png (deflated 38%)
#   adding: processed_dataset/train_comp/4/0030.png (deflated 8%)
#   adding: processed_dataset/train_comp/4/0042.png (deflated 35%)
#   adding: processed_dataset/train_comp/4/0019.png (deflated 12%)
#   adding: processed_dataset/train_comp/4/0000.png (deflated 15%)
#   adding: processed_dataset/train_comp/4/0020.png (deflated 36%)
#   adding: processed_dataset/train_comp/4/0035.png (deflated 6%)
#   adding: processed_dataset/train_comp/7/ (stored 0%)
#   adding: processed_dataset/train_comp/7/0024.png (deflated 8%)
#   adding: processed_dataset/train_comp/7/0036.png (deflated 27%)
#   adding: processed_dataset/train_comp/7/0012.png (deflated 6%)
#   adding: processed_dataset/train_comp/7/0059.png (deflated 29%)
#   adding: processed_dataset/train_comp/7/0065.png (deflated 19%)
#   adding: processed_dataset/train_comp/7/0026.png (deflated 15%)
#   adding: processed_dataset/train_comp/7/0014.png (deflated 35%)
#   adding: processed_dataset/train_comp/7/0064.png (deflated 22%)
#   adding: processed_dataset/train_comp/7/0063.png (deflated 8%)
#   adding: processed_dataset/train_comp/7/0055.png (deflated 66%)
#   adding: processed_dataset/train_comp/7/0008.png (deflated 23%)
#   adding: processed_dataset/train_comp/7/0002.png (deflated 11%)
#   adding: processed_dataset/train_comp/7/0025.png (deflated 8%)
#   adding: processed_dataset/train_comp/7/0039.png (deflated 18%)
#   adding: processed_dataset/train_comp/7/0015.png (deflated 43%)
#   adding: processed_dataset/train_comp/7/0017.png (deflated 13%)
#   adding: processed_dataset/train_comp/7/0057.png (deflated 14%)
#   adding: processed_dataset/train_comp/7/0066.png (deflated 9%)
#   adding: processed_dataset/train_comp/7/0001.png (deflated 5%)
#   adding: processed_dataset/train_comp/7/0051.png (deflated 12%)
#   adding: processed_dataset/train_comp/7/0003.png (deflated 9%)
#   adding: processed_dataset/train_comp/7/0004.png (deflated 4%)
#   adding: processed_dataset/train_comp/7/0049.png (deflated 10%)
#   adding: processed_dataset/train_comp/7/0010.png (deflated 12%)
#   adding: processed_dataset/train_comp/7/0007.png (deflated 22%)
#   adding: processed_dataset/train_comp/7/0023.png (deflated 1%)
#   adding: processed_dataset/train_comp/7/0018.png (deflated 7%)
#   adding: processed_dataset/train_comp/7/0009.png (deflated 5%)
#   adding: processed_dataset/train_comp/7/0013.png (deflated 7%)
#   adding: processed_dataset/train_comp/7/0058.png (deflated 12%)
#   adding: processed_dataset/train_comp/7/0016.png (deflated 17%)
#   adding: processed_dataset/train_comp/7/0047.png (deflated 15%)
#   adding: processed_dataset/train_comp/7/0045.png (deflated 24%)
#   adding: processed_dataset/train_comp/7/0054.png (deflated 25%)
#   adding: processed_dataset/train_comp/7/0032.png (deflated 10%)
#   adding: processed_dataset/train_comp/7/0027.png (deflated 9%)
#   adding: processed_dataset/train_comp/7/0052.png (deflated 19%)
#   adding: processed_dataset/train_comp/7/0043.png (deflated 11%)
#   adding: processed_dataset/train_comp/7/0040.png (deflated 17%)
#   adding: processed_dataset/train_comp/7/0050.png (deflated 12%)
#   adding: processed_dataset/train_comp/7/0046.png (deflated 26%)
#   adding: processed_dataset/train_comp/7/0048.png (deflated 4%)
#   adding: processed_dataset/train_comp/7/0044.png (deflated 7%)
#   adding: processed_dataset/train_comp/7/0041.png (deflated 21%)
#   adding: processed_dataset/train_comp/7/0005.png (deflated 5%)
#   adding: processed_dataset/train_comp/7/0053.png (deflated 27%)
#   adding: processed_dataset/train_comp/7/0011.png (deflated 15%)
#   adding: processed_dataset/train_comp/7/0061.png (deflated 2%)
#   adding: processed_dataset/train_comp/7/0033.png (deflated 4%)
#   adding: processed_dataset/train_comp/7/0038.png (deflated 26%)
#   adding: processed_dataset/train_comp/7/0034.png (deflated 5%)
#   adding: processed_dataset/train_comp/7/0006.png (deflated 24%)
#   adding: processed_dataset/train_comp/7/0029.png (deflated 9%)
#   adding: processed_dataset/train_comp/7/0037.png (deflated 13%)
#   adding: processed_dataset/train_comp/7/0021.png (deflated 8%)
#   adding: processed_dataset/train_comp/7/0022.png (deflated 10%)
#   adding: processed_dataset/train_comp/7/0028.png (deflated 14%)
#   adding: processed_dataset/train_comp/7/0062.png (deflated 5%)
#   adding: processed_dataset/train_comp/7/0060.png (deflated 7%)
#   adding: processed_dataset/train_comp/7/0031.png (deflated 4%)
#   adding: processed_dataset/train_comp/7/0056.png (deflated 6%)
#   adding: processed_dataset/train_comp/7/0030.png (deflated 4%)
#   adding: processed_dataset/train_comp/7/0042.png (deflated 16%)
#   adding: processed_dataset/train_comp/7/0019.png (deflated 8%)
#   adding: processed_dataset/train_comp/7/0000.png (deflated 14%)
#   adding: processed_dataset/train_comp/7/0020.png (deflated 6%)
#   adding: processed_dataset/train_comp/7/0035.png (deflated 6%)
#   adding: processed_dataset/train_comp/0/ (stored 0%)
#   adding: processed_dataset/train_comp/0/0024.png (deflated 16%)
#   adding: processed_dataset/train_comp/0/0036.png (deflated 8%)
#   adding: processed_dataset/train_comp/0/0012.png (deflated 25%)
#   adding: processed_dataset/train_comp/0/0059.png (deflated 15%)
#   adding: processed_dataset/train_comp/0/0065.png (deflated 7%)
#   adding: processed_dataset/train_comp/0/0026.png (deflated 19%)
#   adding: processed_dataset/train_comp/0/0014.png (deflated 8%)
#   adding: processed_dataset/train_comp/0/0064.png (deflated 14%)
#   adding: processed_dataset/train_comp/0/0063.png (deflated 26%)
#   adding: processed_dataset/train_comp/0/0055.png (deflated 10%)
#   adding: processed_dataset/train_comp/0/0008.png (deflated 22%)
#   adding: processed_dataset/train_comp/0/0002.png (deflated 16%)
#   adding: processed_dataset/train_comp/0/0025.png (deflated 10%)
#   adding: processed_dataset/train_comp/0/0039.png (deflated 18%)
#   adding: processed_dataset/train_comp/0/0015.png (deflated 19%)
#   adding: processed_dataset/train_comp/0/0017.png (deflated 29%)
#   adding: processed_dataset/train_comp/0/0057.png (deflated 11%)
#   adding: processed_dataset/train_comp/0/0001.png (deflated 21%)
#   adding: processed_dataset/train_comp/0/0051.png (deflated 13%)
#   adding: processed_dataset/train_comp/0/0003.png (deflated 18%)
#   adding: processed_dataset/train_comp/0/0004.png (deflated 22%)
#   adding: processed_dataset/train_comp/0/0049.png (deflated 11%)
#   adding: processed_dataset/train_comp/0/0010.png (deflated 10%)
#   adding: processed_dataset/train_comp/0/0007.png (deflated 18%)
#   adding: processed_dataset/train_comp/0/0023.png (deflated 10%)
#   adding: processed_dataset/train_comp/0/0018.png (deflated 6%)
#   adding: processed_dataset/train_comp/0/0009.png (deflated 20%)
#   adding: processed_dataset/train_comp/0/0013.png (deflated 13%)
#   adding: processed_dataset/train_comp/0/0058.png (deflated 12%)
#   adding: processed_dataset/train_comp/0/0016.png (deflated 22%)
#   adding: processed_dataset/train_comp/0/0047.png (deflated 12%)
#   adding: processed_dataset/train_comp/0/0045.png (deflated 20%)
#   adding: processed_dataset/train_comp/0/0054.png (deflated 73%)
#   adding: processed_dataset/train_comp/0/0032.png (deflated 7%)
#   adding: processed_dataset/train_comp/0/0027.png (deflated 16%)
#   adding: processed_dataset/train_comp/0/0052.png (deflated 8%)
#   adding: processed_dataset/train_comp/0/0043.png (deflated 25%)
#   adding: processed_dataset/train_comp/0/0040.png (deflated 16%)
#   adding: processed_dataset/train_comp/0/0050.png (deflated 12%)
#   adding: processed_dataset/train_comp/0/0046.png (deflated 16%)
#   adding: processed_dataset/train_comp/0/0048.png (deflated 45%)
#   adding: processed_dataset/train_comp/0/0044.png (deflated 28%)
#   adding: processed_dataset/train_comp/0/0041.png (deflated 14%)
#   adding: processed_dataset/train_comp/0/0005.png (deflated 25%)
#   adding: processed_dataset/train_comp/0/0053.png (deflated 19%)
#   adding: processed_dataset/train_comp/0/0011.png (deflated 22%)
#   adding: processed_dataset/train_comp/0/0061.png (deflated 34%)
#   adding: processed_dataset/train_comp/0/0033.png (deflated 14%)
#   adding: processed_dataset/train_comp/0/0038.png (deflated 29%)
#   adding: processed_dataset/train_comp/0/0034.png (deflated 6%)
#   adding: processed_dataset/train_comp/0/0006.png (deflated 26%)
#   adding: processed_dataset/train_comp/0/0029.png (deflated 13%)
#   adding: processed_dataset/train_comp/0/0037.png (deflated 13%)
#   adding: processed_dataset/train_comp/0/0021.png (deflated 18%)
#   adding: processed_dataset/train_comp/0/0022.png (deflated 11%)
#   adding: processed_dataset/train_comp/0/0028.png (deflated 15%)
#   adding: processed_dataset/train_comp/0/0062.png (deflated 10%)
#   adding: processed_dataset/train_comp/0/0060.png (deflated 22%)
#   adding: processed_dataset/train_comp/0/0031.png (deflated 12%)
#   adding: processed_dataset/train_comp/0/0056.png (deflated 9%)
#   adding: processed_dataset/train_comp/0/0030.png (deflated 10%)
#   adding: processed_dataset/train_comp/0/0042.png (deflated 17%)
#   adding: processed_dataset/train_comp/0/0019.png (deflated 12%)
#   adding: processed_dataset/train_comp/0/0000.png (deflated 15%)
#   adding: processed_dataset/train_comp/0/0020.png (deflated 25%)
#   adding: processed_dataset/train_comp/0/0035.png (deflated 7%)
