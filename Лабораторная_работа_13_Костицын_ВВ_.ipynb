# %% [markdown]
# <a href="https://colab.research.google.com/github/A1ienSword/Pattern-recognition-labs/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_13_%D0%9A%D0%BE%D1%81%D1%82%D0%B8%D1%86%D1%8B%D0%BD_%D0%92%D0%92_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from PIL import Image
import sys
from tqdm import tqdm

# %%
class SimpleCNN(nn.Module):
    def __init__(self, img_size=64, num_classes=37):
        """Простая CNN для классификации изображений.

        Параметры:
            img_size (int): размер входного изображения (по умолчанию 64x64)
            num_classes (int): количество классов для классификации (37 = 10 цифр + 26 букв + 1)
        """
        super(SimpleCNN, self).__init__()
        self.img_size = img_size

        # Первый сверточный слой: 1 входной канал, 16 выходных, ядро 5x5
        self.conv1 = nn.Conv2d(1, 16, kernel_size=5, stride=1, padding=2)

        # Пулинг для уменьшения размерности в 2 раза
        self.pool = nn.MaxPool2d(2, 2)

        # Второй сверточный слой: 16 входных каналов, 32 выходных
        self.conv2 = nn.Conv2d(16, 32, kernel_size=5, stride=1, padding=2)

        # Функция активации ReLU (вынесена в атрибут для переиспользования)
        self.relu = nn.ReLU()

        # Динамическая инициализация полносвязных слоев
        self._init_fc_layers()

        # Финальный классификационный слой
        self.fc2 = nn.Linear(128, num_classes)

    def _init_fc_layers(self):
        """Автоматический расчет входных нейронов для полносвязного слоя"""
        # Генерация тестового тензора для расчета размерности
        test_tensor = torch.randn(1, 1, self.img_size, self.img_size)

        with torch.no_grad():
            # Проход через всю сеть для расчета размеров
            x = self.pool(self.relu(self.conv1(test_tensor)))
            x = self.pool(self.relu(self.conv2(x)))

            # "Выпрямление" тензора для полносвязного слоя
            in_features = x.view(-1).shape[0]

        # Инициализация первого полносвязного слоя
        self.fc1 = nn.Linear(in_features, 128)

    def forward(self, x):
        """Прямой проход через сеть"""
        x = self.pool(self.relu(self.conv1(x)))  # Конволюция + активация + пулинг
        x = self.pool(self.relu(self.conv2(x)))  # Второй сверточный блок

        x = x.view(x.size(0), -1)  # Выпрямление в вектор
        x = self.relu(self.fc1(x))  # Полносвязный слой с активацией
        x = self.fc2(x)             # Финальная классификация
        return x

# %%
def train(data_dir='processed_dataset/train',
          model_path='model.pth',
          img_size=64,
          num_classes=37,
          epochs=3,
          batch_size=64,
          learning_rate=0.001):
    """Функция обучения модели

    Параметры:
        data_dir (str): путь к обучающим данным
        model_path (str): путь для сохранения модели
        img_size (int): размер входных изображений
        num_classes (int): количество классов
        epochs (int): количество эпох обучения
        batch_size (int): размер батча
        learning_rate (float): скорость обучения
    """
    # Преобразования для входных изображений
    transform = transforms.Compose([
        transforms.Grayscale(),              # Конвертация в градации серого
        transforms.Resize((img_size, img_size)),  # Изменение размера
        transforms.ToTensor(),               # Конвертация в тензор
        transforms.Normalize((0.5,), (0.5,)) # Нормализация в диапазон [-1, 1]
    ])

    # Загрузка датасета и создание DataLoader
    train_dataset = datasets.ImageFolder(data_dir, transform=transform)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)

    # Определение устройства для вычислений (GPU/CPU)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = SimpleCNN(img_size=img_size, num_classes=num_classes).to(device)

    # Функция потерь и оптимизатор
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    best_accuracy = 0.0
    progress_bar = tqdm(range(epochs), desc="Обучение модели")

    for epoch in progress_bar:
        model.train()
        total_loss = 0
        correct = 0
        total = 0

        for inputs, labels in tqdm(train_loader, desc=f"Эпоха {epoch+1}", leave=False):
            inputs, labels = inputs.to(device), labels.to(device)

            # Обнуление градиентов
            optimizer.zero_grad()

            # Прямой проход
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Обратное распространение
            loss.backward()
            optimizer.step()

            # Статистика
            total_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        # Вывод статистики
        epoch_accuracy = 100 * correct / total
        progress_bar.set_postfix({
            'loss': f"{total_loss / len(train_loader):.4f}",
            'accuracy': f"{epoch_accuracy:.2f}%"
        })

        # Сохранение лучшей модели
        if epoch_accuracy > best_accuracy:
            best_accuracy = epoch_accuracy
            torch.save({
                'model_state': model.state_dict(),
                'img_size': img_size,
                'num_classes': num_classes
            }, model_path)

    print(f"\nОбучение завершено. Лучшая точность: {best_accuracy:.2f}%")

# %%
def recognize(image_path, model_path='model.pth'):
    """Функция распознавания изображения

    Параметры:
        image_path (str): путь к изображению для классификации
        model_path (str): путь к сохраненной модели
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Загрузка сохраненной модели
    checkpoint = torch.load(model_path, map_location=device)
    img_size = checkpoint['img_size']
    num_classes = checkpoint['num_classes']

    # Инициализация модели
    model = SimpleCNN(img_size=img_size, num_classes=num_classes).to(device)
    model.load_state_dict(checkpoint['model_state'])
    model.eval()  # Режим оценки

    # Преобразования для входного изображения
    transform = transforms.Compose([
        transforms.Grayscale(),
        transforms.Resize((img_size, img_size)),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])

    try:
        # Обработка изображения
        image = Image.open(image_path)
        input_tensor = transform(image).unsqueeze(0).to(device)

        # Предсказание
        with torch.no_grad():
            output = model(input_tensor)
            predicted_class = torch.argmax(output, dim=1).item()

        # Маппинг классов (0-9: цифры, 10-35: A-Z)
        classes = [str(i) for i in range(10)] + [chr(i) for i in range(65, 91)]
        print(f"Предсказанный символ: {classes[predicted_class]}")

    except Exception as e:
        print(f"Ошибка: {str(e)}")

# %%
def test_accuracy(test_dir='processed_dataset/test', model_path='model.pth'):
    """Тестирование точности модели

    Параметры:
        test_dir (str): путь к тестовым данным
        model_path (str): путь к сохраненной модели
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Загрузка модели
    checkpoint = torch.load(model_path, map_location=device)
    img_size = checkpoint['img_size']
    num_classes = checkpoint['num_classes']

    model = SimpleCNN(img_size=img_size, num_classes=num_classes).to(device)
    model.load_state_dict(checkpoint['model_state'])
    model.eval()

    # Преобразования для тестовых данных
    transform = transforms.Compose([
        transforms.Grayscale(),
        transforms.Resize((img_size, img_size)),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])

    # Загрузка тестового датасета
    test_dataset = datasets.ImageFolder(test_dir, transform=transform)
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=2)

    correct = 0
    total = 0
    progress_bar = tqdm(test_loader, desc="Обработка тестовых данных")

    with torch.no_grad():
        for inputs, labels in progress_bar:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            predicted = torch.argmax(outputs, dim=1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

# Эпоха 3:  97%|█████████▋| 36/37 [00:06<00:00,  5.82it/s]
# Эпоха 3: 100%|██████████| 37/37 [00:07<00:00,  5.98it/s]
# Обучение модели: 100%|██████████| 3/3 [00:28<00:00,  9.58s/it, loss=0.8411, accuracy=77.84%]
# Обучение завершено. Лучшая точность: 77.84%

# %%
test_accuracy()
# Out:
# Обработка тестовых данных: 100%|██████████| 18/18 [00:01<00:00, 12.98it/s, Текущая точность=69.39%]
# Общая точность на тестовой выборке: 69.39%

# %%
# !unzip processed_dataset.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: processed_dataset/train/X/0017.png
#   inflating: processed_dataset/train/X/0057.png
#   inflating: processed_dataset/train/X/0001.png
#   inflating: processed_dataset/train/X/0051.png
#  extracting: processed_dataset/train/X/0003.png
#   inflating: processed_dataset/train/X/0004.png
#   inflating: processed_dataset/train/X/0049.png
#   inflating: processed_dataset/train/X/0010.png
#   inflating: processed_dataset/train/X/0007.png
#   inflating: processed_dataset/train/X/0023.png
#   inflating: processed_dataset/train/X/0018.png
#  extracting: processed_dataset/train/X/0009.png
#   inflating: processed_dataset/train/X/0013.png
#   inflating: processed_dataset/train/X/0058.png
#   inflating: processed_dataset/train/X/0016.png
#   inflating: processed_dataset/train/X/0047.png
#   inflating: processed_dataset/train/X/0045.png
#   inflating: processed_dataset/train/X/0054.png
#   inflating: processed_dataset/train/X/0032.png
#  extracting: processed_dataset/train/X/0027.png
#   inflating: processed_dataset/train/X/0052.png
#   inflating: processed_dataset/train/X/0043.png
#   inflating: processed_dataset/train/X/0040.png
#   inflating: processed_dataset/train/X/0050.png
#   inflating: processed_dataset/train/X/0046.png
#   inflating: processed_dataset/train/X/0048.png
#   inflating: processed_dataset/train/X/0044.png
#   inflating: processed_dataset/train/X/0041.png
#   inflating: processed_dataset/train/X/0005.png
#   inflating: processed_dataset/train/X/0053.png
#   inflating: processed_dataset/train/X/0011.png
#   inflating: processed_dataset/train/X/0033.png
#   inflating: processed_dataset/train/X/0038.png
#   inflating: processed_dataset/train/X/0034.png
#   inflating: processed_dataset/train/X/0006.png
#   inflating: processed_dataset/train/X/0029.png
#   inflating: processed_dataset/train/X/0037.png
#   inflating: processed_dataset/train/X/0021.png
#   inflating: processed_dataset/train/X/0022.png
#   inflating: processed_dataset/train/X/0028.png
#   inflating: processed_dataset/train/X/0060.png
#   inflating: processed_dataset/train/X/0031.png
#   inflating: processed_dataset/train/X/0056.png
#   inflating: processed_dataset/train/X/0030.png
#   inflating: processed_dataset/train/X/0042.png
#   inflating: processed_dataset/train/X/0019.png
#   inflating: processed_dataset/train/X/0000.png
#   inflating: processed_dataset/train/X/0020.png
#  extracting: processed_dataset/train/X/0035.png
#    creating: processed_dataset/train/4/
#   inflating: processed_dataset/train/4/0024.png
#   inflating: processed_dataset/train/4/0036.png
#   inflating: processed_dataset/train/4/0012.png
#   inflating: processed_dataset/train/4/0059.png
#   inflating: processed_dataset/train/4/0065.png
#   inflating: processed_dataset/train/4/0026.png
#   inflating: processed_dataset/train/4/0014.png
#   inflating: processed_dataset/train/4/0064.png
#   inflating: processed_dataset/train/7/0008.png
#  extracting: processed_dataset/train/7/0002.png
#   inflating: processed_dataset/train/7/0025.png
#   inflating: processed_dataset/train/7/0039.png
#   inflating: processed_dataset/train/7/0015.png
#   inflating: processed_dataset/train/7/0017.png
#   inflating: processed_dataset/train/7/0057.png
#   inflating: processed_dataset/train/7/0066.png
#   inflating: processed_dataset/train/7/0001.png
#   inflating: processed_dataset/train/7/0051.png
#   inflating: processed_dataset/train/7/0003.png
#   inflating: processed_dataset/train/7/0004.png
#   inflating: processed_dataset/train/7/0049.png
#  extracting: processed_dataset/train/7/0010.png
#  extracting: processed_dataset/train/7/0007.png
#   inflating: processed_dataset/train/7/0023.png
#   inflating: processed_dataset/train/7/0018.png
#   inflating: processed_dataset/train/7/0009.png
#  extracting: processed_dataset/train/7/0013.png
#   inflating: processed_dataset/train/7/0058.png
#   inflating: processed_dataset/train/7/0016.png
#   inflating: processed_dataset/train/7/0047.png
#   inflating: processed_dataset/train/7/0045.png
#   inflating: processed_dataset/train/7/0054.png
#   inflating: processed_dataset/train/7/0032.png
#  extracting: processed_dataset/train/7/0027.png
#   inflating: processed_dataset/train/7/0052.png
#  extracting: processed_dataset/train/7/0043.png
#   inflating: processed_dataset/train/7/0040.png
#   inflating: processed_dataset/train/7/0050.png
#   inflating: processed_dataset/train/7/0046.png
#   inflating: processed_dataset/train/7/0048.png
#   inflating: processed_dataset/train/7/0044.png
#   inflating: processed_dataset/train/7/0041.png
#   inflating: processed_dataset/train/7/0005.png
#   inflating: processed_dataset/train/7/0053.png
#  extracting: processed_dataset/train/7/0011.png
#  extracting: processed_dataset/train/7/0061.png
#   inflating: processed_dataset/train/7/0033.png
#   inflating: processed_dataset/train/7/0038.png
#   inflating: processed_dataset/train/7/0034.png
#   inflating: processed_dataset/train/7/0006.png
#   inflating: processed_dataset/train/7/0029.png
#   inflating: processed_dataset/train/7/0037.png
#   inflating: processed_dataset/train/7/0021.png
#   inflating: processed_dataset/train/7/0022.png
#   inflating: processed_dataset/train/7/0028.png
#   inflating: processed_dataset/train/7/0062.png
#  extracting: processed_dataset/train/7/0060.png
#   inflating: processed_dataset/train/7/0031.png
#   inflating: processed_dataset/train/7/0056.png
#   inflating: processed_dataset/train/7/0030.png
#   inflating: processed_dataset/train/7/0042.png
#   inflating: processed_dataset/train/7/0019.png
#  extracting: processed_dataset/train/7/0000.png
#  extracting: processed_dataset/train/7/0020.png
#  extracting: processed_dataset/train/7/0035.png
#    creating: processed_dataset/train/0/
#   inflating: processed_dataset/train/0/0024.png
#   inflating: processed_dataset/train/0/0036.png
#   inflating: processed_dataset/train/0/0012.png
#   inflating: processed_dataset/train/0/0059.png
#   inflating: processed_dataset/train/0/0065.png
#   inflating: processed_dataset/train/0/0026.png
#  extracting: processed_dataset/train/0/0014.png
#   inflating: processed_dataset/train/0/0064.png
#   inflating: processed_dataset/train/0/0063.png
#   inflating: processed_dataset/train/0/0055.png
#   inflating: processed_dataset/train/0/0008.png
#   inflating: processed_dataset/train/0/0002.png
#   inflating: processed_dataset/train/0/0025.png
#   inflating: processed_dataset/train/0/0039.png
#   inflating: processed_dataset/train/0/0015.png
#   inflating: processed_dataset/train/0/0017.png
#   inflating: processed_dataset/train/0/0057.png
#   inflating: processed_dataset/train/0/0001.png
#   inflating: processed_dataset/train/0/0051.png
#   inflating: processed_dataset/train/0/0003.png
#   inflating: processed_dataset/train/0/0004.png
#   inflating: processed_dataset/train/0/0049.png
#   inflating: processed_dataset/train/0/0010.png
#   inflating: processed_dataset/train/0/0007.png
#   inflating: processed_dataset/train/0/0023.png
#   inflating: processed_dataset/train/0/0018.png
#   inflating: processed_dataset/train/0/0009.png
#   inflating: processed_dataset/train/0/0013.png
#  extracting: processed_dataset/train/0/0058.png
#   inflating: processed_dataset/train/0/0016.png
#   inflating: processed_dataset/train/0/0047.png
#   inflating: processed_dataset/train/0/0045.png
#   inflating: processed_dataset/train/0/0054.png
#   inflating: processed_dataset/train/0/0032.png
#   inflating: processed_dataset/train/0/0027.png
#  extracting: processed_dataset/train/0/0052.png
#   inflating: processed_dataset/train/0/0043.png
#   inflating: processed_dataset/train/0/0040.png
#   inflating: processed_dataset/train/0/0050.png
#   inflating: processed_dataset/train/0/0046.png
#   inflating: processed_dataset/train/0/0048.png
#   inflating: processed_dataset/train/0/0044.png
#   inflating: processed_dataset/train/0/0041.png
#   inflating: processed_dataset/train/0/0005.png
#   inflating: processed_dataset/train/0/0053.png
#   inflating: processed_dataset/train/0/0011.png
#   inflating: processed_dataset/train/0/0061.png
#   inflating: processed_dataset/train/0/0033.png
#   inflating: processed_dataset/train/0/0038.png
#  extracting: processed_dataset/train/0/0034.png
#   inflating: processed_dataset/train/0/0006.png
#   inflating: processed_dataset/train/0/0029.png
#   inflating: processed_dataset/train/0/0037.png
#   inflating: processed_dataset/train/0/0021.png
#   inflating: processed_dataset/train/0/0022.png
#   inflating: processed_dataset/train/0/0028.png
#   inflating: processed_dataset/train/0/0062.png
#   inflating: processed_dataset/train/0/0060.png
#   inflating: processed_dataset/train/0/0031.png
#   inflating: processed_dataset/train/0/0056.png
#   inflating: processed_dataset/train/0/0030.png
#   inflating: processed_dataset/train/0/0042.png
#   inflating: processed_dataset/train/0/0019.png
#   inflating: processed_dataset/train/0/0000.png
#   inflating: processed_dataset/train/0/0020.png
#  extracting: processed_dataset/train/0/0035.png
#    creating: processed_dataset/test_comp/
#    creating: processed_dataset/test_comp/E/
#   inflating: processed_dataset/test_comp/E/0024.png
#   inflating: processed_dataset/test_comp/E/0012.png
#   inflating: processed_dataset/test_comp/E/0026.png
#   inflating: processed_dataset/test_comp/E/0014.png
#   inflating: processed_dataset/test_comp/E/0008.png
#   inflating: processed_dataset/test_comp/E/0002.png
#   inflating: processed_dataset/test_comp/E/0025.png
#   inflating: processed_dataset/test_comp/E/0015.png
#   inflating: processed_dataset/test_comp/E/0017.png
#   inflating: processed_dataset/test_comp/E/0001.png
#   inflating: processed_dataset/test_comp/E/0003.png
#   inflating: processed_dataset/test_comp/E/0004.png
#   inflating: processed_dataset/test_comp/E/0010.png
#   inflating: processed_dataset/test_comp/E/0007.png
#    creating: processed_dataset/test_comp/Q/
#   inflating: processed_dataset/test_comp/Q/0024.png
#   inflating: processed_dataset/test_comp/Q/0012.png
#   inflating: processed_dataset/test_comp/Q/0026.png
#   inflating: processed_dataset/test_comp/Q/0014.png
#   inflating: processed_dataset/test_comp/Q/0008.png
#   inflating: processed_dataset/test_comp/Q/0002.png
#   inflating: processed_dataset/test_comp/Q/0025.png
#   inflating: processed_dataset/test_comp/Q/0015.png
#   inflating: processed_dataset/test_comp/Q/0017.png
#   inflating: processed_dataset/test_comp/Q/0001.png
#   inflating: processed_dataset/test_comp/Q/0003.png
#   inflating: processed_dataset/test_comp/Q/0004.png
#   inflating: processed_dataset/test_comp/Q/0010.png
#   inflating: processed_dataset/test_comp/Q/0007.png
#   inflating: processed_dataset/test_comp/Q/0023.png
#   inflating: processed_dataset/test_comp/Q/0018.png
#   inflating: processed_dataset/test_comp/Q/0009.png
#   inflating: processed_dataset/test_comp/Q/0013.png
#   inflating: processed_dataset/test_comp/Q/0016.png
#   inflating: processed_dataset/test_comp/Q/0027.png
#   inflating: processed_dataset/test_comp/Q/0005.png
#   inflating: processed_dataset/test_comp/Q/0011.png
#   inflating: processed_dataset/test_comp/Q/0006.png
#   inflating: processed_dataset/test_comp/Q/0029.png
#   inflating: processed_dataset/test_comp/Q/0021.png
#   inflating: processed_dataset/test_comp/Q/0022.png
#   inflating: processed_dataset/test_comp/Q/0028.png
#   inflating: processed_dataset/test_comp/Q/0030.png
#   inflating: processed_dataset/test_comp/Q/0019.png
#   inflating: processed_dataset/test_comp/Q/0000.png
#   inflating: processed_dataset/test_comp/Q/0020.png
#    creating: processed_dataset/test_comp/O/
#   inflating: processed_dataset/test_comp/O/0024.png
#   inflating: processed_dataset/test_comp/O/0012.png
#   inflating: processed_dataset/test_comp/O/0026.png
#   inflating: processed_dataset/test_comp/O/0014.png
#   inflating: processed_dataset/test_comp/O/0008.png
#   inflating: processed_dataset/test_comp/O/0002.png
#   inflating: processed_dataset/test_comp/O/0025.png
#   inflating: processed_dataset/test_comp/O/0015.png
#   inflating: processed_dataset/test_comp/O/0017.png
#   inflating: processed_dataset/test_comp/O/0001.png
#   inflating: processed_dataset/test_comp/O/0003.png
#   inflating: processed_dataset/test_comp/O/0004.png
#   inflating: processed_dataset/test_comp/O/0010.png
#   inflating: processed_dataset/test_comp/O/0007.png
#   inflating: processed_dataset/test_comp/O/0023.png
#   inflating: processed_dataset/test_comp/O/0018.png
#   inflating: processed_dataset/test_comp/O/0009.png
#   inflating: processed_dataset/test_comp/O/0013.png
#   inflating: processed_dataset/test_comp/O/0016.png
#   inflating: processed_dataset/test_comp/O/0027.png
#   inflating: processed_dataset/test_comp/O/0005.png
#   inflating: processed_dataset/test_comp/O/0011.png
#   inflating: processed_dataset/test_comp/O/0006.png
#   inflating: processed_dataset/test_comp/O/0029.png
#   inflating: processed_dataset/test_comp/O/0021.png
#   inflating: processed_dataset/test_comp/O/0022.png
#   inflating: processed_dataset/test_comp/O/0028.png
#   inflating: processed_dataset/test_comp/O/0019.png
#   inflating: processed_dataset/test_comp/O/0000.png
#   inflating: processed_dataset/test_comp/O/0020.png
#    creating: processed_dataset/test_comp/M/
#   inflating: processed_dataset/test_comp/M/0024.png
#   inflating: processed_dataset/test_comp/M/0012.png
#   inflating: processed_dataset/test_comp/M/0026.png
#   inflating: processed_dataset/test_comp/M/0014.png
#   inflating: processed_dataset/test_comp/M/0008.png
#   inflating: processed_dataset/test_comp/M/0002.png
#   inflating: processed_dataset/test_comp/M/0025.png
#   inflating: processed_dataset/test_comp/M/0015.png
#   inflating: processed_dataset/test_comp/M/0017.png
#   inflating: processed_dataset/test_comp/M/0001.png
#   inflating: processed_dataset/test_comp/M/0003.png
#   inflating: processed_dataset/test_comp/M/0004.png
#   inflating: processed_dataset/test_comp/M/0010.png
#   inflating: processed_dataset/test_comp/M/0007.png
#   inflating: processed_dataset/test_comp/M/0023.png
#   inflating: processed_dataset/test_comp/M/0018.png
#   inflating: processed_dataset/test_comp/M/0009.png
#   inflating: processed_dataset/test_comp/M/0013.png
#   inflating: processed_dataset/test_comp/M/0016.png
#   inflating: processed_dataset/test_comp/M/0032.png
#   inflating: processed_dataset/test_comp/M/0027.png
#   inflating: processed_dataset/test_comp/M/0005.png
#   inflating: processed_dataset/test_comp/M/0011.png
#   inflating: processed_dataset/test_comp/M/0006.png
#   inflating: processed_dataset/test_comp/M/0029.png
#   inflating: processed_dataset/test_comp/M/0021.png
#   inflating: processed_dataset/test_comp/M/0022.png
#   inflating: processed_dataset/test_comp/M/0028.png
#   inflating: processed_dataset/test_comp/M/0031.png
#   inflating: processed_dataset/test_comp/M/0030.png
#   inflating: processed_dataset/test_comp/M/0019.png
#   inflating: processed_dataset/test_comp/M/0000.png
#   inflating: processed_dataset/test_comp/M/0020.png
#    creating: processed_dataset/test_comp/D/
#   inflating: processed_dataset/test_comp/D/0024.png
#   inflating: processed_dataset/test_comp/D/0012.png
#   inflating: processed_dataset/test_comp/D/0026.png
#   inflating: processed_dataset/test_comp/D/0014.png
#   inflating: processed_dataset/test_comp/D/0008.png
#   inflating: processed_dataset/test_comp/D/0002.png
#   inflating: processed_dataset/test_comp/D/0025.png
#   inflating: processed_dataset/test_comp/D/0015.png
#   inflating: processed_dataset/test_comp/D/0017.png
#   inflating: processed_dataset/test_comp/D/0001.png
#   inflating: processed_dataset/test_comp/D/0003.png
#   inflating: processed_dataset/test_comp/D/0004.png
#   inflating: processed_dataset/test_comp/D/0010.png
#   inflating: processed_dataset/test_comp/D/0007.png
#   inflating: processed_dataset/test_comp/D/0023.png
#   inflating: processed_dataset/test_comp/D/0018.png
#   inflating: processed_dataset/test_comp/D/0009.png
#   inflating: processed_dataset/test_comp/D/0013.png
#   inflating: processed_dataset/test_comp/D/0016.png
#   inflating: processed_dataset/test_comp/D/0027.png
#   inflating: processed_dataset/test_comp/D/0005.png
#   inflating: processed_dataset/test_comp/D/0011.png
#   inflating: processed_dataset/test_comp/D/0006.png
#   inflating: processed_dataset/test_comp/D/0029.png
#   inflating: processed_dataset/test_comp/D/0021.png
#   inflating: processed_dataset/test_comp/D/0022.png
#   inflating: processed_dataset/test_comp/D/0028.png
#   inflating: processed_dataset/test_comp/D/0030.png
#   inflating: processed_dataset/test_comp/D/0019.png
#   inflating: processed_dataset/test_comp/D/0000.png
#   inflating: processed_dataset/test_comp/D/0020.png
#    creating: processed_dataset/test_comp/K/
#   inflating: processed_dataset/test_comp/K/0024.png
#   inflating: processed_dataset/test_comp/K/0012.png
#   inflating: processed_dataset/test_comp/K/0026.png
#   inflating: processed_dataset/test_comp/K/0014.png
#   inflating: processed_dataset/test_comp/K/0008.png
#   inflating: processed_dataset/test_comp/K/0002.png
#   inflating: processed_dataset/test_comp/K/0025.png
#   inflating: processed_dataset/test_comp/K/0015.png
#   inflating: processed_dataset/test_comp/K/0017.png
#   inflating: processed_dataset/test_comp/K/0001.png
#   inflating: processed_dataset/test_comp/K/0003.png
#   inflating: processed_dataset/test_comp/K/0004.png
#   inflating: processed_dataset/test_comp/K/0010.png
#   inflating: processed_dataset/test_comp/K/0007.png
#   inflating: processed_dataset/test_comp/K/0023.png
#   inflating: processed_dataset/test_comp/K/0018.png
#   inflating: processed_dataset/test_comp/K/0009.png
#   inflating: processed_dataset/test_comp/K/0013.png
#   inflating: processed_dataset/test_comp/K/0016.png
#   inflating: processed_dataset/test_comp/K/0027.png
#   inflating: processed_dataset/test_comp/K/0005.png
#   inflating: processed_dataset/test_comp/K/0011.png
#   inflating: processed_dataset/test_comp/K/0006.png
#   inflating: processed_dataset/test_comp/K/0029.png
#   inflating: processed_dataset/test_comp/K/0021.png
#   inflating: processed_dataset/test_comp/K/0022.png
#   inflating: processed_dataset/test_comp/K/0028.png
#   inflating: processed_dataset/test_comp/K/0031.png
#   inflating: processed_dataset/test_comp/K/0030.png
#   inflating: processed_dataset/test_comp/K/0019.png
#   inflating: processed_dataset/test_comp/K/0000.png
#   inflating: processed_dataset/test_comp/K/0020.png
#    creating: processed_dataset/test_comp/T/
#   inflating: processed_dataset/test_comp/T/0024.png
#   inflating: processed_dataset/test_comp/T/0012.png
#   inflating: processed_dataset/test_comp/T/0026.png
#   inflating: processed_dataset/test_comp/T/0014.png
#   inflating: processed_dataset/test_comp/T/0008.png
#   inflating: processed_dataset/test_comp/T/0002.png
#   inflating: processed_dataset/test_comp/T/0025.png
#   inflating: processed_dataset/test_comp/T/0015.png
#   inflating: processed_dataset/test_comp/T/0017.png
#   inflating: processed_dataset/test_comp/T/0001.png
#   inflating: processed_dataset/test_comp/T/0003.png
#   inflating: processed_dataset/test_comp/T/0004.png
#   inflating: processed_dataset/test_comp/T/0010.png
#   inflating: processed_dataset/test_comp/T/0007.png
#   inflating: processed_dataset/test_comp/T/0023.png
#   inflating: processed_dataset/test_comp/T/0018.png
#   inflating: processed_dataset/test_comp/T/0009.png
#   inflating: processed_dataset/test_comp/T/0013.png
#   inflating: processed_dataset/test_comp/T/0016.png
#   inflating: processed_dataset/test_comp/T/0027.png
#   inflating: processed_dataset/test_comp/T/0005.png
#   inflating: processed_dataset/test_comp/T/0011.png
#   inflating: processed_dataset/test_comp/T/0006.png
#   inflating: processed_dataset/test_comp/T/0029.png
#   inflating: processed_dataset/test_comp/T/0021.png
#   inflating: processed_dataset/test_comp/T/0022.png
#   inflating: processed_dataset/test_comp/T/0028.png
#   inflating: processed_dataset/test_comp/T/0031.png
#   inflating: processed_dataset/test_comp/T/0030.png
#   inflating: processed_dataset/test_comp/T/0019.png
#   inflating: processed_dataset/test_comp/T/0000.png
#   inflating: processed_dataset/test_comp/T/0020.png
#    creating: processed_dataset/test_comp/J/
#   inflating: processed_dataset/test_comp/J/0024.png
#   inflating: processed_dataset/test_comp/J/0012.png
#   inflating: processed_dataset/test_comp/J/0026.png
#   inflating: processed_dataset/test_comp/J/0014.png
#   inflating: processed_dataset/test_comp/J/0008.png
#   inflating: processed_dataset/test_comp/J/0002.png
#   inflating: processed_dataset/test_comp/J/0025.png
#   inflating: processed_dataset/test_comp/J/0015.png
#   inflating: processed_dataset/test_comp/J/0017.png
#   inflating: processed_dataset/test_comp/J/0001.png
#   inflating: processed_dataset/test_comp/J/0003.png
#   inflating: processed_dataset/test_comp/J/0004.png
#   inflating: processed_dataset/test_comp/J/0010.png
#   inflating: processed_dataset/test_comp/J/0007.png
#   inflating: processed_dataset/test_comp/J/0023.png
#   inflating: processed_dataset/test_comp/J/0018.png
#   inflating: processed_dataset/test_comp/J/0009.png
#   inflating: processed_dataset/test_comp/J/0013.png
#   inflating: processed_dataset/test_comp/J/0016.png
#   inflating: processed_dataset/test_comp/J/0027.png
#   inflating: processed_dataset/test_comp/J/0005.png
#   inflating: processed_dataset/test_comp/J/0011.png
#   inflating: processed_dataset/test_comp/J/0006.png
#   inflating: processed_dataset/test_comp/J/0029.png
#   inflating: processed_dataset/test_comp/J/0021.png
#   inflating: processed_dataset/test_comp/J/0022.png
#   inflating: processed_dataset/test_comp/J/0028.png
#   inflating: processed_dataset/test_comp/J/0030.png
#   inflating: processed_dataset/test_comp/J/0019.png
#   inflating: processed_dataset/test_comp/J/0000.png
#   inflating: processed_dataset/test_comp/J/0020.png
#    creating: processed_dataset/test_comp/I/
#   inflating: processed_dataset/test_comp/I/0024.png
#   inflating: processed_dataset/test_comp/I/0012.png
#   inflating: processed_dataset/test_comp/I/0026.png
#   inflating: processed_dataset/test_comp/I/0014.png
#   inflating: processed_dataset/test_comp/I/0008.png
#   inflating: processed_dataset/test_comp/I/0002.png
#   inflating: processed_dataset/test_comp/I/0025.png
#   inflating: processed_dataset/test_comp/I/0015.png
#   inflating: processed_dataset/test_comp/I/0017.png
#   inflating: processed_dataset/test_comp/I/0001.png
#   inflating: processed_dataset/test_comp/I/0003.png
#   inflating: processed_dataset/test_comp/I/0004.png
#   inflating: processed_dataset/test_comp/I/0010.png
#   inflating: processed_dataset/test_comp/I/0007.png
#   inflating: processed_dataset/test_comp/I/0023.png
#   inflating: processed_dataset/test_comp/I/0018.png
#   inflating: processed_dataset/test_comp/I/0009.png
#   inflating: processed_dataset/test_comp/I/0013.png
#   inflating: processed_dataset/test_comp/I/0016.png
#   inflating: processed_dataset/test_comp/I/0027.png
#   inflating: processed_dataset/test_comp/I/0005.png
#   inflating: processed_dataset/test_comp/I/0011.png
#   inflating: processed_dataset/test_comp/I/0006.png
#   inflating: processed_dataset/test_comp/I/0029.png
#   inflating: processed_dataset/test_comp/I/0021.png
#   inflating: processed_dataset/test_comp/I/0022.png
#   inflating: processed_dataset/test_comp/I/0028.png
#   inflating: processed_dataset/test_comp/I/0031.png
#   inflating: processed_dataset/test_comp/I/0030.png
#   inflating: processed_dataset/test_comp/I/0019.png
#   inflating: processed_dataset/test_comp/I/0000.png
#   inflating: processed_dataset/test_comp/I/0020.png
#    creating: processed_dataset/test_comp/2/
#   inflating: processed_dataset/test_comp/2/0024.png
#   inflating: processed_dataset/test_comp/2/0012.png
#   inflating: processed_dataset/test_comp/2/0026.png
#   inflating: processed_dataset/test_comp/2/0014.png
#   inflating: processed_dataset/test_comp/2/0008.png
#   inflating: processed_dataset/test_comp/2/0002.png
#   inflating: processed_dataset/test_comp/2/0025.png
#   inflating: processed_dataset/test_comp/2/0015.png
#   inflating: processed_dataset/test_comp/2/0017.png
#   inflating: processed_dataset/test_comp/2/0001.png
#   inflating: processed_dataset/test_comp/2/0003.png
#   inflating: processed_dataset/test_comp/2/0004.png
#   inflating: processed_dataset/test_comp/2/0010.png
#   inflating: processed_dataset/test_comp/2/0007.png
#   inflating: processed_dataset/test_comp/2/0023.png
#   inflating: processed_dataset/test_comp/2/0018.png
#   inflating: processed_dataset/test_comp/2/0009.png
#   inflating: processed_dataset/test_comp/2/0013.png
#   inflating: processed_dataset/test_comp/2/0016.png
#   inflating: processed_dataset/test_comp/2/0027.png
#   inflating: processed_dataset/test_comp/2/0005.png
#   inflating: processed_dataset/test_comp/2/0011.png
#   inflating: processed_dataset/test_comp/2/0006.png
#   inflating: processed_dataset/test_comp/2/0029.png
#   inflating: processed_dataset/test_comp/2/0021.png
#   inflating: processed_dataset/test_comp/2/0022.png
#   inflating: processed_dataset/test_comp/2/0028.png
#   inflating: processed_dataset/test_comp/2/0031.png
#   inflating: processed_dataset/test_comp/2/0030.png
#   inflating: processed_dataset/test_comp/2/0019.png
#   inflating: processed_dataset/test_comp/2/0000.png
#   inflating: processed_dataset/test_comp/2/0020.png
#    creating: processed_dataset/test_comp/C/
#   inflating: processed_dataset/test_comp/C/0024.png
#   inflating: processed_dataset/test_comp/C/0012.png
#   inflating: processed_dataset/test_comp/C/0026.png
#   inflating: processed_dataset/test_comp/C/0014.png
#   inflating: processed_dataset/test_comp/C/0008.png
#   inflating: processed_dataset/test_comp/C/0002.png
#   inflating: processed_dataset/test_comp/C/0025.png
#   inflating: processed_dataset/test_comp/C/0015.png
#   inflating: processed_dataset/test_comp/C/0017.png
#   inflating: processed_dataset/test_comp/C/0001.png
#   inflating: processed_dataset/test_comp/C/0003.png
#   inflating: processed_dataset/test_comp/C/0004.png
#   inflating: processed_dataset/test_comp/C/0010.png
#   inflating: processed_dataset/test_comp/C/0007.png
#   inflating: processed_dataset/test_comp/C/0023.png
#   inflating: processed_dataset/test_comp/C/0018.png
#   inflating: processed_dataset/test_comp/C/0009.png
#   inflating: processed_dataset/test_comp/C/0013.png
#   inflating: processed_dataset/test_comp/C/0016.png
#   inflating: processed_dataset/test_comp/C/0027.png
#   inflating: processed_dataset/test_comp/C/0005.png
#   inflating: processed_dataset/test_comp/C/0011.png
#   inflating: processed_dataset/test_comp/C/0006.png
#   inflating: processed_dataset/test_comp/C/0029.png
#   inflating: processed_dataset/test_comp/C/0021.png
#   inflating: processed_dataset/test_comp/C/0022.png
#   inflating: processed_dataset/test_comp/C/0028.png
#  extracting: processed_dataset/test_comp/C/0031.png
#   inflating: processed_dataset/test_comp/C/0030.png
#   inflating: processed_dataset/test_comp/C/0019.png
#   inflating: processed_dataset/test_comp/C/0000.png
#   inflating: processed_dataset/test_comp/C/0020.png
#    creating: processed_dataset/test_comp/B/
#   inflating: processed_dataset/test_comp/B/0024.png
#   inflating: processed_dataset/test_comp/B/0012.png
#   inflating: processed_dataset/test_comp/B/0026.png
#   inflating: processed_dataset/test_comp/B/0014.png
#   inflating: processed_dataset/test_comp/B/0008.png
#   inflating: processed_dataset/test_comp/B/0002.png
#   inflating: processed_dataset/test_comp/B/0025.png
#   inflating: processed_dataset/test_comp/B/0015.png
#   inflating: processed_dataset/test_comp/B/0017.png
#   inflating: processed_dataset/test_comp/B/0001.png
#   inflating: processed_dataset/test_comp/B/0003.png
#   inflating: processed_dataset/test_comp/B/0004.png
#   inflating: processed_dataset/test_comp/B/0010.png
#   inflating: processed_dataset/test_comp/B/0007.png
#   inflating: processed_dataset/test_comp/B/0023.png
#   inflating: processed_dataset/test_comp/B/0018.png
#   inflating: processed_dataset/test_comp/B/0009.png
#   inflating: processed_dataset/test_comp/B/0013.png
#   inflating: processed_dataset/test_comp/B/0016.png
#   inflating: processed_dataset/test_comp/B/0032.png
#   inflating: processed_dataset/test_comp/B/0027.png
#   inflating: processed_dataset/test_comp/B/0005.png
#   inflating: processed_dataset/test_comp/B/0011.png
#   inflating: processed_dataset/test_comp/B/0006.png
#   inflating: processed_dataset/test_comp/B/0029.png
#   inflating: processed_dataset/test_comp/B/0021.png
#   inflating: processed_dataset/test_comp/B/0022.png
#   inflating: processed_dataset/test_comp/B/0028.png
#   inflating: processed_dataset/test_comp/B/0031.png
#   inflating: processed_dataset/test_comp/B/0030.png
#   inflating: processed_dataset/test_comp/B/0019.png
#   inflating: processed_dataset/test_comp/B/0000.png
#   inflating: processed_dataset/test_comp/B/0020.png
#    creating: processed_dataset/test_comp/P/
#   inflating: processed_dataset/test_comp/P/0024.png
#   inflating: processed_dataset/test_comp/P/0012.png
#   inflating: processed_dataset/test_comp/P/0026.png
#   inflating: processed_dataset/test_comp/P/0014.png
#   inflating: processed_dataset/test_comp/P/0008.png
#   inflating: processed_dataset/test_comp/P/0002.png
#   inflating: processed_dataset/test_comp/P/0025.png
#   inflating: processed_dataset/test_comp/P/0015.png
#   inflating: processed_dataset/test_comp/P/0017.png
#   inflating: processed_dataset/test_comp/P/0001.png
#   inflating: processed_dataset/test_comp/P/0003.png
#   inflating: processed_dataset/test_comp/P/0004.png
#   inflating: processed_dataset/test_comp/P/0010.png
#   inflating: processed_dataset/test_comp/P/0007.png
#   inflating: processed_dataset/test_comp/P/0023.png
#   inflating: processed_dataset/test_comp/P/0018.png
#   inflating: processed_dataset/test_comp/P/0009.png
#   inflating: processed_dataset/test_comp/P/0013.png
#   inflating: processed_dataset/test_comp/P/0016.png
#   inflating: processed_dataset/test_comp/P/0027.png
#   inflating: processed_dataset/test_comp/P/0005.png
#   inflating: processed_dataset/test_comp/P/0011.png
#   inflating: processed_dataset/test_comp/P/0006.png
#   inflating: processed_dataset/test_comp/P/0029.png
#   inflating: processed_dataset/test_comp/P/0021.png
#   inflating: processed_dataset/test_comp/P/0022.png
#   inflating: processed_dataset/test_comp/P/0028.png
#   inflating: processed_dataset/test_comp/P/0030.png
#   inflating: processed_dataset/test_comp/P/0019.png
#   inflating: processed_dataset/test_comp/P/0000.png
#   inflating: processed_dataset/test_comp/P/0020.png
# ...
#   inflating: processed_dataset/train_comp/Z/0048.png
#   inflating: processed_dataset/train_comp/Z/0044.png
#   inflating: processed_dataset/train_comp/Z/0041.png
#   inflating: processed_dataset/train_comp/Z/0005.png
#   inflating: processed_dataset/train_comp/Z/0053.png
#  extracting: processed_dataset/train_comp/Z/0011.png
#   inflating: processed_dataset/train_comp/Z/0061.png
#   inflating: processed_dataset/train_comp/Z/0033.png
#   inflating: processed_dataset/train_comp/Z/0038.png
#   inflating: processed_dataset/train_comp/Z/0034.png
#   inflating: processed_dataset/train_comp/Z/0006.png
#   inflating: processed_dataset/train_comp/Z/0029.png
#   inflating: processed_dataset/train_comp/Z/0037.png
#   inflating: processed_dataset/train_comp/Z/0021.png
#   inflating: processed_dataset/train_comp/Z/0022.png
#   inflating: processed_dataset/train_comp/Z/0028.png
#   inflating: processed_dataset/train_comp/Z/0062.png
#  extracting: processed_dataset/train_comp/Z/0060.png
#   inflating: processed_dataset/train_comp/Z/0031.png
#   inflating: processed_dataset/train_comp/Z/0056.png
#   inflating: processed_dataset/train_comp/Z/0030.png
#   inflating: processed_dataset/train_comp/Z/0042.png
#   inflating: processed_dataset/train_comp/Z/0019.png
#  extracting: processed_dataset/train_comp/Z/0000.png
#   inflating: processed_dataset/train_comp/Z/0020.png
#   inflating: processed_dataset/train_comp/Z/0035.png
#    creating: processed_dataset/train_comp/X/
#   inflating: processed_dataset/train_comp/X/0024.png
#   inflating: processed_dataset/train_comp/X/0036.png
#   inflating: processed_dataset/train_comp/X/0012.png
#   inflating: processed_dataset/train_comp/X/0059.png
#   inflating: processed_dataset/train_comp/X/0026.png
#   inflating: processed_dataset/train_comp/X/0014.png
#   inflating: processed_dataset/train_comp/X/0055.png
#   inflating: processed_dataset/train_comp/X/0008.png
#   inflating: processed_dataset/train_comp/X/0002.png
#   inflating: processed_dataset/train_comp/X/0025.png
#   inflating: processed_dataset/train_comp/X/0039.png
#   inflating: processed_dataset/train_comp/X/0015.png
#   inflating: processed_dataset/train_comp/X/0017.png
#   inflating: processed_dataset/train_comp/X/0057.png
#   inflating: processed_dataset/train_comp/X/0001.png
#   inflating: processed_dataset/train_comp/0/0065.png
#   inflating: processed_dataset/train_comp/0/0026.png
#   inflating: processed_dataset/train_comp/0/0014.png
#   inflating: processed_dataset/train_comp/0/0064.png
#   inflating: processed_dataset/train_comp/0/0063.png
#   inflating: processed_dataset/train_comp/0/0055.png
#   inflating: processed_dataset/train_comp/0/0008.png
#   inflating: processed_dataset/train_comp/0/0002.png
#   inflating: processed_dataset/train_comp/0/0025.png
#   inflating: processed_dataset/train_comp/0/0039.png
#   inflating: processed_dataset/train_comp/0/0015.png
#   inflating: processed_dataset/train_comp/0/0017.png
#   inflating: processed_dataset/train_comp/0/0057.png
#   inflating: processed_dataset/train_comp/0/0001.png
#   inflating: processed_dataset/train_comp/0/0051.png
#   inflating: processed_dataset/train_comp/0/0003.png
#   inflating: processed_dataset/train_comp/0/0004.png
#   inflating: processed_dataset/train_comp/0/0049.png
#   inflating: processed_dataset/train_comp/0/0010.png
#   inflating: processed_dataset/train_comp/0/0007.png
#   inflating: processed_dataset/train_comp/0/0023.png
#   inflating: processed_dataset/train_comp/0/0018.png
#   inflating: processed_dataset/train_comp/0/0009.png
#   inflating: processed_dataset/train_comp/0/0013.png
#   inflating: processed_dataset/train_comp/0/0058.png
#   inflating: processed_dataset/train_comp/0/0016.png
#   inflating: processed_dataset/train_comp/0/0047.png
#   inflating: processed_dataset/train_comp/0/0045.png
#   inflating: processed_dataset/train_comp/0/0054.png
#   inflating: processed_dataset/train_comp/0/0032.png
#   inflating: processed_dataset/train_comp/0/0027.png
#   inflating: processed_dataset/train_comp/0/0052.png
#   inflating: processed_dataset/train_comp/0/0043.png
#   inflating: processed_dataset/train_comp/0/0040.png
#   inflating: processed_dataset/train_comp/0/0050.png
#   inflating: processed_dataset/train_comp/0/0046.png
#   inflating: processed_dataset/train_comp/0/0048.png
#   inflating: processed_dataset/train_comp/0/0044.png
#   inflating: processed_dataset/train_comp/0/0041.png
#   inflating: processed_dataset/train_comp/0/0005.png
#   inflating: processed_dataset/train_comp/0/0053.png
#   inflating: processed_dataset/train_comp/0/0011.png
#   inflating: processed_dataset/train_comp/0/0061.png
#   inflating: processed_dataset/train_comp/0/0033.png
#   inflating: processed_dataset/train_comp/0/0038.png
#   inflating: processed_dataset/train_comp/0/0034.png
#   inflating: processed_dataset/train_comp/0/0006.png
#   inflating: processed_dataset/train_comp/0/0029.png
#   inflating: processed_dataset/train_comp/0/0037.png
#   inflating: processed_dataset/train_comp/0/0021.png
#   inflating: processed_dataset/train_comp/0/0022.png
#   inflating: processed_dataset/train_comp/0/0028.png
#   inflating: processed_dataset/train_comp/0/0062.png
#   inflating: processed_dataset/train_comp/0/0060.png
#   inflating: processed_dataset/train_comp/0/0031.png
#   inflating: processed_dataset/train_comp/0/0056.png
#   inflating: processed_dataset/train_comp/0/0030.png
#   inflating: processed_dataset/train_comp/0/0042.png
#   inflating: processed_dataset/train_comp/0/0019.png
#   inflating: processed_dataset/train_comp/0/0000.png
#   inflating: processed_dataset/train_comp/0/0020.png
#   inflating: processed_dataset/train_comp/0/0035.png
